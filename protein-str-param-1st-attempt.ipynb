# %% [markdown]
# <a href="https://colab.research.google.com/github/eoinleen/Protein-design-random/blob/main/protein-str-param-1st-attempt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required packages
# !pip install biopython freesasa numpy

# Import required libraries
import os
import sys
from Bio import PDB
from Bio.PDB.PDBIO import PDBIO
from Bio.PDB.Polypeptide import is_aa
import freesasa
import numpy as np
from google.colab import drive

# Mount Google Drive (if not already mounted)
try:
    drive.mount('/content/drive')
except:
    print("Drive already mounted or mounting failed")

# Rest of the code remains the same as before
def calculate_buried_surface_area(pdb_file):
    """Calculate buried surface area between chains in a PDB structure."""
    parser = PDB.PDBParser(QUIET=True)
    structure = parser.get_structure('protein', pdb_file)

    chains = list(structure.get_chains())
    if len(chains) < 2:
        return None, None

    # Calculate surface area for complete structure
    structure_atoms = [atom for atom in structure.get_atoms()]
    if not structure_atoms:
        return None, None

    combined_structure = freesasa.Structure(pdb_file)
    result = freesasa.calc(combined_structure)
    total_area = result.totalArea()

    # Calculate individual chain areas
    chain_areas = {}
    io = PDBIO()
    for chain in chains:
        # Create a new structure with just this chain
        new_structure = PDB.Structure.Structure('temp')
        new_model = PDB.Model.Model(0)
        new_structure.add(new_model)
        new_chain = chain.copy()
        new_model.add(new_chain)

        # Save temporary file
        temp_file = f"temp_chain_{chain.id}.pdb"
        io.set_structure(new_structure)
        io.save(temp_file)

        # Calculate area
        chain_structure = freesasa.Structure(temp_file)
        chain_result = freesasa.calc(chain_structure)
        chain_areas[chain.id] = chain_result.totalArea()

        # Clean up
        os.remove(temp_file)

    # Calculate buried surface area
    total_individual_area = sum(chain_areas.values())
    buried_surface_area = total_individual_area - total_area

    return abs(buried_surface_area), chain_areas

def calculate_hydrogen_bonds(structure):
    """Calculate hydrogen bonds between chains using distance and angle criteria."""
    h_bonds = []
    for chain1 in structure.get_chains():
        for chain2 in structure.get_chains():
            if chain1.id != chain2.id:
                for res1 in chain1.get_residues():
                    if not is_aa(res1):
                        continue
                    for res2 in chain2.get_residues():
                        if not is_aa(res2):
                            continue
                        # Check for backbone-backbone H-bonds
                        if 'O' in res1 and 'N' in res2:
                            distance = res1['O'] - res2['N']
                            if distance < 3.5:  # Standard H-bond distance cutoff
                                h_bonds.append((res1, res2))
    return len(h_bonds)

def calculate_hydrophobic_contacts(structure):
    """Calculate hydrophobic contacts between chains."""
    hydrophobic_residues = {'ALA', 'VAL', 'LEU', 'ILE', 'MET', 'PHE', 'TRP', 'PRO'}
    contacts = []

    for chain1 in structure.get_chains():
        for chain2 in structure.get_chains():
            if chain1.id >= chain2.id:
                continue

            for res1 in chain1.get_residues():
                if not is_aa(res1) or res1.get_resname() not in hydrophobic_residues:
                    continue

                for res2 in chain2.get_residues():
                    if not is_aa(res2) or res2.get_resname() not in hydrophobic_residues:
                        continue

                    # Calculate minimum distance between any atoms in the residues
                    min_distance = float('inf')
                    for atom1 in res1.get_atoms():
                        for atom2 in res2.get_atoms():
                            distance = atom1 - atom2
                            min_distance = min(min_distance, distance)

                    if min_distance < 5.0:  # Distance threshold for hydrophobic contact
                        contacts.append((res1, res2))

    return len(contacts)

def calculate_salt_bridges(structure):
    """Calculate salt bridges between chains."""
    acidic = {'ASP', 'GLU'}
    basic = {'LYS', 'ARG', 'HIS'}
    salt_bridges = []

    for chain1 in structure.get_chains():
        for chain2 in structure.get_chains():
            if chain1.id >= chain2.id:
                continue

            for res1 in chain1.get_residues():
                if not is_aa(res1):
                    continue
                res1_name = res1.get_resname()

                for res2 in chain2.get_residues():
                    if not is_aa(res2):
                        continue
                    res2_name = res2.get_resname()

                    # Check if residues can form salt bridge
                    if (res1_name in acidic and res2_name in basic) or \
                       (res1_name in basic and res2_name in acidic):
                        # Calculate distance between charged groups
                        min_distance = float('inf')
                        for atom1 in res1.get_atoms():
                            for atom2 in res2.get_atoms():
                                distance = atom1 - atom2
                                min_distance = min(min_distance, distance)

                        if min_distance < 4.0:  # Distance threshold for salt bridge
                            salt_bridges.append((res1, res2))

    return len(salt_bridges)

def process_multiple_pdb_files(pdb_directory):
    """Process multiple PDB files and analyze their structures."""
    results = []
    parser = PDB.PDBParser(QUIET=True)

    for file_name in os.listdir(pdb_directory):
        if not file_name.endswith(".pdb"):
            continue

        pdb_file = os.path.join(pdb_directory, file_name)
        print(f"\nProcessing {file_name}")

        try:
            # Load structure
            structure = parser.get_structure('protein', pdb_file)

            # Calculate metrics
            buried_surface_area, chain_areas = calculate_buried_surface_area(pdb_file)
            h_bonds = calculate_hydrogen_bonds(structure)
            hydrophobic = calculate_hydrophobic_contacts(structure)
            salt_bridges = calculate_salt_bridges(structure)

            results.append({
                'file_name': file_name,
                'buried_surface_area': buried_surface_area,
                'hydrogen_bonds': h_bonds,
                'hydrophobic_contacts': hydrophobic,
                'salt_bridges': salt_bridges,
                'chain_areas': chain_areas
            })

            # Print detailed results for this structure
            print(f"Buried Surface Area: {buried_surface_area:.2f} Å²" if buried_surface_area else "Buried Surface Area: Not applicable")
            print(f"Hydrogen Bonds: {h_bonds}")
            print(f"Hydrophobic Contacts: {hydrophobic}")
            print(f"Salt Bridges: {salt_bridges}")

        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}")

    return results

def print_summary_report(results):
    """Print a formatted summary report of all results."""
    print("\nSummary Report:")
    print(f"{'PDB File':<30} {'Buried Surface Area (Å²)':<25} {'H-Bonds':<12} {'Hydrophobic':<12} {'Salt Bridges':<12}")
    print("="*90)

    for result in results:
        bsa = f"{result['buried_surface_area']:.2f}" if result['buried_surface_area'] else "N/A"
        print(f"{result['file_name']:<30} {bsa:<25} {result['hydrogen_bonds']:<12} "
              f"{result['hydrophobic_contacts']:<12} {result['salt_bridges']:<12}")

# Main execution
# Update this path to your PDB files directory in Google Drive
pdb_directory = '/content/drive/MyDrive/PDB-files/all_pdb-2MBO-no-hot'  # Update this path as needed

print("Starting analysis...")
results = process_multiple_pdb_files(pdb_directory)
print_summary_report(results)
# Out:
# Requirement already satisfied: biopython in /usr/local/lib/python3.11/dist-packages (1.85)
# Requirement already satisfied: freesasa in /usr/local/lib/python3.11/dist-packages (2.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting analysis...
#
# Processing design0_n16.pdb
# Buried Surface Area: 1904.15 Å²
# Hydrogen Bonds: 17
# Hydrophobic Contacts: 11
# Salt Bridges: 2
#
# Processing design0_n1.pdb
# Buried Surface Area: 1593.75 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 15
# Salt Bridges: 3
#
# Processing design0_n13.pdb
# Buried Surface Area: 1344.79 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design0_n10.pdb
# Buried Surface Area: 1698.90 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 12
# Salt Bridges: 1
#
# Processing design0_n12.pdb
# Buried Surface Area: 1983.12 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 20
# Salt Bridges: 2
#
# Processing design0_n15.pdb
# Buried Surface Area: 1417.30 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 11
# Salt Bridges: 5
#
# Processing design1_n1.pdb
# Buried Surface Area: 1805.60 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 12
# Salt Bridges: 2
#
# Processing design0_n0.pdb
# Buried Surface Area: 1349.91 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 16
# Salt Bridges: 3
#
# Processing design1_n11.pdb
# Buried Surface Area: 1273.78 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 6
# Salt Bridges: 2
#
# Processing design0_n14.pdb
# Buried Surface Area: 1050.12 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 6
# Salt Bridges: 4
#
# Processing design0_n9.pdb
# Buried Surface Area: 1381.45 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 2
#
# Processing design0_n11.pdb
# Buried Surface Area: 1655.80 Å²
# Hydrogen Bonds: 18
# Hydrophobic Contacts: 32
# Salt Bridges: 0
#
# Processing design1_n0.pdb
# Buried Surface Area: 1381.74 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 0
#
# Processing design1_n12.pdb
# Buried Surface Area: 1637.55 Å²
# Hydrogen Bonds: 12
# Hydrophobic Contacts: 14
# Salt Bridges: 5
#
# Processing design0_n8.pdb
# Buried Surface Area: 1919.16 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 28
# Salt Bridges: 3
#
# Processing design0_n63.pdb
# Buried Surface Area: 1750.71 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 19
# Salt Bridges: 1
#
# Processing design1_n10.pdb
# Buried Surface Area: 1323.52 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 14
# Salt Bridges: 1
#
# Processing design0_n7.pdb
# Buried Surface Area: 1673.73 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 19
# Salt Bridges: 3
#
# Processing design0_n62.pdb
# Buried Surface Area: 1556.93 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 10
# Salt Bridges: 0
#
# Processing design0_n6.pdb
# Buried Surface Area: 1298.58 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 0
#
# Processing design0_n60.pdb
# Buried Surface Area: 1400.08 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 3
#
# Processing design0_n58.pdb
# Buried Surface Area: 1950.43 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 19
# Salt Bridges: 4
#
# Processing design0_n56.pdb
# Buried Surface Area: 1071.18 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 13
# Salt Bridges: 1
#
# Processing design0_n61.pdb
# Buried Surface Area: 1106.16 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design0_n59.pdb
# Buried Surface Area: 1447.00 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 1
#
# Processing design0_n55.pdb
# Buried Surface Area: 1670.66 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 18
# Salt Bridges: 4
#
# Processing design0_n57.pdb
# Buried Surface Area: 1418.73 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 3
# Salt Bridges: 3
#
# Processing design0_n54.pdb
# Buried Surface Area: 1764.02 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 14
# Salt Bridges: 6
#
# Processing design0_n53.pdb
# Buried Surface Area: 1475.59 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 4
#
# Processing design0_n51.pdb
# Buried Surface Area: 1104.93 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 16
# Salt Bridges: 2
#
# Processing design0_n50.pdb
# Buried Surface Area: 1475.38 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 4
#
# Processing design0_n45.pdb
# Buried Surface Area: 1144.75 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 3
#
# Processing design0_n48.pdb
# Buried Surface Area: 1438.85 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 15
# Salt Bridges: 0
#
# Processing design0_n47.pdb
# Buried Surface Area: 1039.05 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 2
#
# Processing design0_n5.pdb
# Buried Surface Area: 1215.33 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 11
# Salt Bridges: 3
#
# Processing design0_n52.pdb
# Buried Surface Area: 1442.57 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 17
# Salt Bridges: 2
#
# Processing design0_n49.pdb
# Buried Surface Area: 1778.36 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 16
# Salt Bridges: 3
#
# Processing design0_n46.pdb
# Buried Surface Area: 1944.44 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 3
#
# Processing design0_n42.pdb
# Buried Surface Area: 1831.65 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 23
# Salt Bridges: 3
#
# Processing design0_n40.pdb
# Buried Surface Area: 1816.76 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 17
# Salt Bridges: 6
#
# Processing design0_n39.pdb
# Buried Surface Area: 2010.33 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 27
# Salt Bridges: 1
#
# Processing design0_n43.pdb
# Buried Surface Area: 1660.56 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 21
# Salt Bridges: 5
#
# Processing design0_n41.pdb
# Buried Surface Area: 1472.54 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 15
# Salt Bridges: 3
#
# Processing design0_n38.pdb
# Buried Surface Area: 1706.33 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 15
# Salt Bridges: 3
#
# Processing design0_n4.pdb
# Buried Surface Area: 1760.51 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 25
# Salt Bridges: 0
#
# Processing design0_n44.pdb
# Buried Surface Area: 1512.96 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design0_n37.pdb
# Buried Surface Area: 1237.19 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design0_n36.pdb
# Buried Surface Area: 1974.90 Å²
# Hydrogen Bonds: 11
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design0_n34.pdb
# Buried Surface Area: 1802.91 Å²
# Hydrogen Bonds: 17
# Hydrophobic Contacts: 31
# Salt Bridges: 1
#
# Processing design0_n30.pdb
# Buried Surface Area: 1539.86 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 3
#
# Processing design0_n3.pdb
# Buried Surface Area: 1353.07 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 4
#
# Processing design0_n27.pdb
# Buried Surface Area: 1338.96 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 11
# Salt Bridges: 2
#
# Processing design0_n32.pdb
# Buried Surface Area: 1875.50 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 19
# Salt Bridges: 3
#
# Processing design0_n35.pdb
# Buried Surface Area: 1648.88 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 3
#
# Processing design0_n33.pdb
# Buried Surface Area: 1977.15 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 20
# Salt Bridges: 6
#
# Processing design0_n31.pdb
# Buried Surface Area: 1742.82 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 5
#
# Processing design0_n25.pdb
# Buried Surface Area: 1358.58 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 6
# Salt Bridges: 2
#
# Processing design0_n29.pdb
# Buried Surface Area: 1768.26 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 3
#
# Processing design0_n28.pdb
# Buried Surface Area: 1726.34 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 19
# Salt Bridges: 4
#
# Processing design0_n22.pdb
# Buried Surface Area: 1534.18 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design0_n21.pdb
# Buried Surface Area: 1531.43 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 4
#
# Processing design0_n19.pdb
# Buried Surface Area: 1474.17 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 3
#
# Processing design0_n20.pdb
# Buried Surface Area: 1696.66 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 4
#
# Processing design0_n26.pdb
# Buried Surface Area: 1146.71 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design0_n2.pdb
# Buried Surface Area: 1807.49 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design0_n23.pdb
# Buried Surface Area: 1379.35 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design0_n24.pdb
# Buried Surface Area: 1783.82 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 15
# Salt Bridges: 7
#
# Processing design0_n18.pdb
# Buried Surface Area: 1566.85 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design0_n17.pdb
# Buried Surface Area: 1621.69 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 3
#
# Processing design1_n14.pdb
# Buried Surface Area: 1623.45 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 13
# Salt Bridges: 0
#
# Processing design1_n13.pdb
# Buried Surface Area: 1753.36 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 20
# Salt Bridges: 1
#
# Processing design1_n19.pdb
# Buried Surface Area: 1771.76 Å²
# Hydrogen Bonds: 7
# Hydrophobic Contacts: 16
# Salt Bridges: 1
#
# Processing design2_n1.pdb
# Buried Surface Area: 2246.00 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 15
# Salt Bridges: 4
#
# Processing design1_n8.pdb
# Buried Surface Area: 1698.74 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 17
# Salt Bridges: 3
#
# Processing design2_n0.pdb
# Buried Surface Area: 1227.71 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design1_n61.pdb
# Buried Surface Area: 1412.56 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 17
# Salt Bridges: 1
#
# Processing design1_n62.pdb
# Buried Surface Area: 1730.23 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 10
# Salt Bridges: 2
#
# Processing design1_n9.pdb
# Buried Surface Area: 1375.34 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 13
# Salt Bridges: 3
#
# Processing design1_n7.pdb
# Buried Surface Area: 1690.01 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 15
# Salt Bridges: 2
#
# Processing design1_n63.pdb
# Buried Surface Area: 1557.05 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 2
#
# Processing design1_n60.pdb
# Buried Surface Area: 1707.13 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 1
#
# Processing design1_n6.pdb
# Buried Surface Area: 1835.03 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 20
# Salt Bridges: 1
#
# Processing design1_n58.pdb
# Buried Surface Area: 1326.06 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 0
#
# Processing design1_n56.pdb
# Buried Surface Area: 1771.33 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 1
#
# Processing design1_n54.pdb
# Buried Surface Area: 1367.53 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design1_n55.pdb
# Buried Surface Area: 1652.30 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design1_n51.pdb
# Buried Surface Area: 1607.07 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design1_n57.pdb
# Buried Surface Area: 1691.16 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 5
#
# Processing design1_n53.pdb
# Buried Surface Area: 2200.64 Å²
# Hydrogen Bonds: 17
# Hydrophobic Contacts: 24
# Salt Bridges: 7
#
# Processing design1_n52.pdb
# Buried Surface Area: 1203.75 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design1_n59.pdb
# Buried Surface Area: 1960.52 Å²
# Hydrogen Bonds: 7
# Hydrophobic Contacts: 22
# Salt Bridges: 2
#
# Processing design1_n50.pdb
# Buried Surface Area: 1846.03 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 0
#
# Processing design1_n49.pdb
# Buried Surface Area: 1413.38 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 1
#
# Processing design1_n47.pdb
# Buried Surface Area: 1688.31 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 18
# Salt Bridges: 1
#
# Processing design1_n44.pdb
# Buried Surface Area: 815.65 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 3
# Salt Bridges: 1
#
# Processing design1_n48.pdb
# Buried Surface Area: 1705.37 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 20
# Salt Bridges: 0
#
# Processing design1_n43.pdb
# Buried Surface Area: 1175.95 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 5
# Salt Bridges: 0
#
# Processing design1_n5.pdb
# Buried Surface Area: 1626.90 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design1_n42.pdb
# Buried Surface Area: 1895.31 Å²
# Hydrogen Bonds: 12
# Hydrophobic Contacts: 16
# Salt Bridges: 4
#
# Processing design1_n45.pdb
# Buried Surface Area: 1267.57 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 2
#
# Processing design1_n46.pdb
# Buried Surface Area: 1747.80 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 20
# Salt Bridges: 0
#
# Processing design1_n41.pdb
# Buried Surface Area: 1798.02 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 15
# Salt Bridges: 5
#
# Processing design1_n4.pdb
# Buried Surface Area: 2040.65 Å²
# Hydrogen Bonds: 9
# Hydrophobic Contacts: 24
# Salt Bridges: 0
#
# Processing design1_n37.pdb
# Buried Surface Area: 1634.37 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 2
#
# Processing design1_n39.pdb
# Buried Surface Area: 1446.91 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 1
#
# Processing design1_n33.pdb
# Buried Surface Area: 1591.15 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 15
# Salt Bridges: 2
#
# Processing design1_n35.pdb
# Buried Surface Area: 2004.15 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 16
# Salt Bridges: 1
#
# Processing design1_n40.pdb
# Buried Surface Area: 1584.16 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 3
#
# Processing design1_n36.pdb
# Buried Surface Area: 1806.56 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 25
# Salt Bridges: 1
#
# Processing design1_n24.pdb
# Buried Surface Area: 1819.11 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 18
# Salt Bridges: 2
#
# Processing design1_n21.pdb
# Buried Surface Area: 1568.46 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 16
# Salt Bridges: 2
#
# Processing design1_n25.pdb
# Buried Surface Area: 1429.36 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 1
#
# Processing design1_n28.pdb
# Buried Surface Area: 1793.08 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 8
# Salt Bridges: 2
#
# Processing design1_n23.pdb
# Buried Surface Area: 1146.89 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 8
# Salt Bridges: 2
#
# Processing design1_n26.pdb
# Buried Surface Area: 1818.65 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 19
# Salt Bridges: 2
#
# Processing design1_n29.pdb
# Buried Surface Area: 1404.53 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 0
#
# Processing design1_n30.pdb
# Buried Surface Area: 1323.57 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 1
#
# Processing design1_n3.pdb
# Buried Surface Area: 1841.68 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 22
# Salt Bridges: 2
#
# Processing design1_n27.pdb
# Buried Surface Area: 1949.01 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 17
# Salt Bridges: 3
#
# Processing design1_n31.pdb
# Buried Surface Area: 1075.20 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 0
#
# Processing design1_n32.pdb
# Buried Surface Area: 1804.02 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 20
# Salt Bridges: 2
#
# Processing design1_n2.pdb
# Buried Surface Area: 1130.14 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 1
#
# Processing design1_n34.pdb
# Buried Surface Area: 1816.02 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 19
# Salt Bridges: 0
#
# Processing design1_n38.pdb
# Buried Surface Area: 1441.54 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 2
#
# Processing design1_n22.pdb
# Buried Surface Area: 1671.57 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design1_n16.pdb
# Buried Surface Area: 1713.50 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 3
#
# Processing design1_n20.pdb
# Buried Surface Area: 1738.75 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design1_n18.pdb
# Buried Surface Area: 1510.08 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 16
# Salt Bridges: 2
#
# Processing design1_n15.pdb
# Buried Surface Area: 1754.27 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 16
# Salt Bridges: 5
#
# Processing design1_n17.pdb
# Buried Surface Area: 1423.35 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 12
# Salt Bridges: 2
#
# Processing design2_n62.pdb
# Buried Surface Area: 997.09 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 2
# Salt Bridges: 1
#
# Processing design2_n63.pdb
# Buried Surface Area: 1072.05 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 0
# Salt Bridges: 4
#
# Processing design2_n58.pdb
# Buried Surface Area: 1736.73 Å²
# Hydrogen Bonds: 7
# Hydrophobic Contacts: 13
# Salt Bridges: 4
#
# Processing design2_n60.pdb
# Buried Surface Area: 1454.64 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 1
#
# Processing design2_n57.pdb
# Buried Surface Area: 1476.15 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 4
# Salt Bridges: 3
#
# Processing design2_n59.pdb
# Buried Surface Area: 1473.53 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 4
#
# Processing design2_n7.pdb
# Buried Surface Area: 1876.37 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 12
# Salt Bridges: 3
#
# Processing design2_n6.pdb
# Buried Surface Area: 515.01 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 3
# Salt Bridges: 1
#
# Processing design2_n61.pdb
# Buried Surface Area: 1762.91 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 18
# Salt Bridges: 2
#
# Processing design2_n56.pdb
# Buried Surface Area: 1361.29 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 6
# Salt Bridges: 1
#
# Processing design2_n54.pdb
# Buried Surface Area: 1475.32 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 18
# Salt Bridges: 3
#
# Processing design2_n53.pdb
# Buried Surface Area: 1450.06 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 13
# Salt Bridges: 4
#
# Processing design2_n50.pdb
# Buried Surface Area: 2222.88 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 18
# Salt Bridges: 3
#
# Processing design2_n47.pdb
# Buried Surface Area: 1461.13 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 6
# Salt Bridges: 1
#
# Processing design2_n5.pdb
# Buried Surface Area: 1752.49 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design2_n52.pdb
# Buried Surface Area: 1346.62 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 10
# Salt Bridges: 2
#
# Processing design2_n49.pdb
# Buried Surface Area: 1225.94 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 3
# Salt Bridges: 2
#
# Processing design2_n55.pdb
# Buried Surface Area: 1232.20 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 4
#
# Processing design2_n51.pdb
# Buried Surface Area: 1246.27 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 13
# Salt Bridges: 1
#
# Processing design2_n48.pdb
# Buried Surface Area: 2138.78 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 18
# Salt Bridges: 2
#
# Processing design2_n43.pdb
# Buried Surface Area: 1261.78 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 8
# Salt Bridges: 1
#
# Processing design2_n46.pdb
# Buried Surface Area: 912.87 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 2
# Salt Bridges: 1
#
# Processing design2_n41.pdb
# Buried Surface Area: 1856.59 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design2_n42.pdb
# Buried Surface Area: 1241.66 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 3
#
# Processing design2_n45.pdb
# Buried Surface Area: 1504.49 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design2_n39.pdb
# Buried Surface Area: 447.67 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 2
# Salt Bridges: 1
#
# Processing design2_n4.pdb
# Buried Surface Area: 1651.39 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 11
# Salt Bridges: 2
#
# Processing design2_n44.pdb
# Buried Surface Area: 1459.45 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 2
#
# Processing design2_n40.pdb
# Buried Surface Area: 1339.90 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 1
#
# Processing design2_n38.pdb
# Buried Surface Area: 1856.20 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 12
# Salt Bridges: 3
#
# Processing design2_n28.pdb
# Buried Surface Area: 1536.54 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 9
# Salt Bridges: 0
#
# Processing design2_n31.pdb
# Buried Surface Area: 988.07 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 8
# Salt Bridges: 3
#
# Processing design2_n34.pdb
# Buried Surface Area: 1499.28 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design2_n29.pdb
# Buried Surface Area: 1523.90 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 15
# Salt Bridges: 0
#
# Processing design2_n33.pdb
# Buried Surface Area: 1131.58 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 5
# Salt Bridges: 0
#
# Processing design2_n35.pdb
# Buried Surface Area: 1715.05 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 10
# Salt Bridges: 0
#
# Processing design2_n3.pdb
# Buried Surface Area: 1105.67 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 5
# Salt Bridges: 0
#
# Processing design2_n30.pdb
# Buried Surface Area: 1607.48 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design2_n32.pdb
# Buried Surface Area: 1947.51 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 22
# Salt Bridges: 4
#
# Processing design2_n36.pdb
# Buried Surface Area: 1359.70 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 4
#
# Processing design2_n25.pdb
# Buried Surface Area: 1434.58 Å²
# Hydrogen Bonds: 9
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design2_n37.pdb
# Buried Surface Area: 1285.27 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 3
# Salt Bridges: 1
#
# Processing design2_n24.pdb
# Buried Surface Area: 1639.92 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 15
# Salt Bridges: 1
#
# Processing design2_n22.pdb
# Buried Surface Area: 1593.74 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 7
#
# Processing design2_n27.pdb
# Buried Surface Area: 1137.18 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 5
# Salt Bridges: 2
#
# Processing design2_n23.pdb
# Buried Surface Area: 1388.94 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 4
#
# Processing design2_n21.pdb
# Buried Surface Area: 1923.02 Å²
# Hydrogen Bonds: 7
# Hydrophobic Contacts: 23
# Salt Bridges: 4
#
# Processing design2_n20.pdb
# Buried Surface Area: 1519.60 Å²
# Hydrogen Bonds: 24
# Hydrophobic Contacts: 12
# Salt Bridges: 6
#
# Processing design2_n26.pdb
# Buried Surface Area: 1025.97 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 6
# Salt Bridges: 0
#
# Processing design2_n2.pdb
# Buried Surface Area: 1282.80 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 22
# Salt Bridges: 0
#
# Processing design2_n18.pdb
# Buried Surface Area: 1650.58 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 20
# Salt Bridges: 1
#
# Processing design2_n17.pdb
# Buried Surface Area: 1365.90 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 8
# Salt Bridges: 4
#
# Processing design2_n13.pdb
# Buried Surface Area: 1493.92 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 10
# Salt Bridges: 0
#
# Processing design2_n16.pdb
# Buried Surface Area: 1342.59 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 7
# Salt Bridges: 4
#
# Processing design2_n11.pdb
# Buried Surface Area: 1202.02 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 7
# Salt Bridges: 1
#
# Processing design2_n12.pdb
# Buried Surface Area: 1845.42 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 3
# Salt Bridges: 4
#
# Processing design2_n19.pdb
# Buried Surface Area: 1690.63 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 8
# Salt Bridges: 5
#
# Processing design2_n14.pdb
# Buried Surface Area: 1726.53 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 18
# Salt Bridges: 1
#
# Processing design2_n15.pdb
# Buried Surface Area: 1373.11 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 13
# Salt Bridges: 3
#
# Processing design2_n10.pdb
# Buried Surface Area: 1101.76 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design3_n61.pdb
# Buried Surface Area: 2287.34 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 20
# Salt Bridges: 3
#
# Processing design3_n60.pdb
# Buried Surface Area: 681.15 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 1
# Salt Bridges: 3
#
# Processing design3_n6.pdb
# Buried Surface Area: 1905.58 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 6
#
# Processing design3_n57.pdb
# Buried Surface Area: 1376.78 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 1
#
# Processing design3_n56.pdb
# Buried Surface Area: 1765.39 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 9
# Salt Bridges: 4
#
# Processing design3_n58.pdb
# Buried Surface Area: 1309.64 Å²
# Hydrogen Bonds: 7
# Hydrophobic Contacts: 9
# Salt Bridges: 3
#
# Processing design3_n54.pdb
# Buried Surface Area: 2001.02 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 11
# Salt Bridges: 4
#
# Processing design3_n59.pdb
# Buried Surface Area: 762.97 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 2
# Salt Bridges: 0
#
# Processing design3_n53.pdb
# Buried Surface Area: 1182.28 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 1
#
# Processing design3_n51.pdb
# Buried Surface Area: 1946.48 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 9
# Salt Bridges: 6
#
# Processing design3_n52.pdb
# Buried Surface Area: 1053.59 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 11
# Salt Bridges: 0
#
# Processing design3_n55.pdb
# Buried Surface Area: 1481.32 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 13
# Salt Bridges: 3
#
# Processing design3_n48.pdb
# Buried Surface Area: 2021.54 Å²
# Hydrogen Bonds: 9
# Hydrophobic Contacts: 11
# Salt Bridges: 6
#
# Processing design3_n49.pdb
# Buried Surface Area: 3287.90 Å²
# Hydrogen Bonds: 21
# Hydrophobic Contacts: 34
# Salt Bridges: 5
#
# Processing design3_n45.pdb
# Buried Surface Area: 938.40 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 0
#
# Processing design3_n5.pdb
# Buried Surface Area: 1412.75 Å²
# Hydrogen Bonds: 25
# Hydrophobic Contacts: 11
# Salt Bridges: 6
#
# Processing design3_n50.pdb
# Buried Surface Area: 2006.99 Å²
# Hydrogen Bonds: 18
# Hydrophobic Contacts: 6
# Salt Bridges: 7
#
# Processing design3_n43.pdb
# Buried Surface Area: 2242.67 Å²
# Hydrogen Bonds: 10
# Hydrophobic Contacts: 19
# Salt Bridges: 6
#
# Processing design3_n46.pdb
# Buried Surface Area: 2113.68 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 13
# Salt Bridges: 5
#
# Processing design3_n47.pdb
# Buried Surface Area: 1707.63 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 10
# Salt Bridges: 3
#
# Processing design3_n44.pdb
# Buried Surface Area: 2211.08 Å²
# Hydrogen Bonds: 19
# Hydrophobic Contacts: 31
# Salt Bridges: 4
#
# Processing design3_n42.pdb
# Buried Surface Area: 1365.06 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 7
# Salt Bridges: 1
#
# Processing design3_n41.pdb
# Buried Surface Area: 1100.15 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 1
#
# Processing design3_n39.pdb
# Buried Surface Area: 1555.55 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 19
# Salt Bridges: 2
#
# Processing design3_n38.pdb
# Buried Surface Area: 1159.16 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 8
# Salt Bridges: 1
#
# Processing design3_n37.pdb
# Buried Surface Area: 2640.96 Å²
# Hydrogen Bonds: 12
# Hydrophobic Contacts: 22
# Salt Bridges: 4
#
# Processing design3_n35.pdb
# Buried Surface Area: 1632.90 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design3_n40.pdb
# Buried Surface Area: 1451.09 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 5
# Salt Bridges: 3
#
# Processing design3_n4.pdb
# Buried Surface Area: 1564.34 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 17
# Salt Bridges: 4
#
# Processing design3_n36.pdb
# Buried Surface Area: 1959.42 Å²
# Hydrogen Bonds: 7
# Hydrophobic Contacts: 15
# Salt Bridges: 1
#
# Processing design3_n34.pdb
# Buried Surface Area: 1195.45 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 3
#
# Processing design3_n32.pdb
# Buried Surface Area: 1636.23 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 3
#
# Processing design3_n30.pdb
# Buried Surface Area: 1221.98 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 4
# Salt Bridges: 2
#
# Processing design3_n31.pdb
# Buried Surface Area: 1624.95 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 8
# Salt Bridges: 9
#
# Processing design3_n3.pdb
# Buried Surface Area: 1669.53 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design3_n27.pdb
# Buried Surface Area: 2275.10 Å²
# Hydrogen Bonds: 15
# Hydrophobic Contacts: 11
# Salt Bridges: 8
#
# Processing design3_n28.pdb
# Buried Surface Area: 717.99 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 1
#
# Processing design3_n33.pdb
# Buried Surface Area: 899.78 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 3
# Salt Bridges: 1
#
# Processing design3_n25.pdb
# Buried Surface Area: 2597.68 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 24
# Salt Bridges: 5
#
# Processing design3_n26.pdb
# Buried Surface Area: 1053.68 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 9
# Salt Bridges: 1
#
# Processing design3_n29.pdb
# Buried Surface Area: 1588.08 Å²
# Hydrogen Bonds: 10
# Hydrophobic Contacts: 12
# Salt Bridges: 7
#
# Processing design3_n23.pdb
# Buried Surface Area: 1305.90 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 14
# Salt Bridges: 0
#
# Processing design3_n21.pdb
# Buried Surface Area: 1612.34 Å²
# Hydrogen Bonds: 9
# Hydrophobic Contacts: 4
# Salt Bridges: 8
#
# Processing design3_n20.pdb
# Buried Surface Area: 1076.50 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 3
#
# Processing design2_n8.pdb
# Buried Surface Area: 1867.59 Å²
# Hydrogen Bonds: 19
# Hydrophobic Contacts: 24
# Salt Bridges: 3
#
# Processing design3_n19.pdb
# Buried Surface Area: 2017.25 Å²
# Hydrogen Bonds: 11
# Hydrophobic Contacts: 8
# Salt Bridges: 5
#
# Processing design3_n1.pdb
# Buried Surface Area: 1648.71 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 3
#
# Processing design3_n11.pdb
# Buried Surface Area: 2521.42 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 31
# Salt Bridges: 3
#
# Processing design3_n14.pdb
# Buried Surface Area: 1120.61 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 0
#
# Processing design2_n9.pdb
# Buried Surface Area: 1691.96 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 6
# Salt Bridges: 3
#
# Processing design3_n12.pdb
# Buried Surface Area: 951.79 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 4
# Salt Bridges: 4
#
# Processing design3_n10.pdb
# Buried Surface Area: 2159.02 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 16
# Salt Bridges: 2
#
# Processing design3_n0.pdb
# Buried Surface Area: 2245.59 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 12
# Salt Bridges: 4
#
# Processing design3_n15.pdb
# Buried Surface Area: 1855.79 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 2
#
# Processing design3_n13.pdb
# Buried Surface Area: 1798.43 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 16
# Salt Bridges: 5
#
# Processing design3_n16.pdb
# Buried Surface Area: 1447.90 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 2
#
# Processing design3_n2.pdb
# Buried Surface Area: 1401.11 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 10
# Salt Bridges: 2
#
# Processing design3_n18.pdb
# Buried Surface Area: 2486.33 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 16
# Salt Bridges: 5
#
# Processing design3_n24.pdb
# Buried Surface Area: 1553.83 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 1
#
# Processing design3_n22.pdb
# Buried Surface Area: 1671.45 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 14
# Salt Bridges: 1
#
# Processing design3_n17.pdb
# Buried Surface Area: 1788.05 Å²
# Hydrogen Bonds: 16
# Hydrophobic Contacts: 15
# Salt Bridges: 2
#
# Processing design4_n58.pdb
# Buried Surface Area: 1490.14 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 17
# Salt Bridges: 0
#
# Processing design4_n7.pdb
# Buried Surface Area: 1390.33 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 6
# Salt Bridges: 0
#
# Processing design4_n62.pdb
# Buried Surface Area: 1169.99 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 11
# Salt Bridges: 3
#
# Processing design4_n9.pdb
# Buried Surface Area: 1827.84 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 1
#
# Processing design4_n6.pdb
# Buried Surface Area: 1629.81 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 8
# Salt Bridges: 3
#
# Processing design4_n56.pdb
# Buried Surface Area: 1497.44 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design4_n59.pdb
# Buried Surface Area: 2040.89 Å²
# Hydrogen Bonds: 10
# Hydrophobic Contacts: 15
# Salt Bridges: 0
#
# Processing design4_n52.pdb
# Buried Surface Area: 1584.15 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 16
# Salt Bridges: 0
#
# Processing design4_n55.pdb
# Buried Surface Area: 975.81 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 9
# Salt Bridges: 0
#
# Processing design4_n57.pdb
# Buried Surface Area: 1494.07 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design4_n50.pdb
# Buried Surface Area: 1057.93 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 3
# Salt Bridges: 1
#
# Processing design4_n54.pdb
# Buried Surface Area: 1749.27 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 10
# Salt Bridges: 2
#
# Processing design4_n5.pdb
# Buried Surface Area: 1073.34 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 7
# Salt Bridges: 0
#
# Processing design4_n53.pdb
# Buried Surface Area: 1563.69 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 5
#
# Processing design4_n49.pdb
# Buried Surface Area: 1251.50 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 9
# Salt Bridges: 1
#
# Processing design4_n51.pdb
# Buried Surface Area: 1287.91 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 2
#
# Processing design4_n44.pdb
# Buried Surface Area: 1298.67 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 10
# Salt Bridges: 0
#
# Processing design4_n42.pdb
# Buried Surface Area: 1647.33 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 14
# Salt Bridges: 4
#
# Processing design4_n40.pdb
# Buried Surface Area: 1902.00 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 13
# Salt Bridges: 1
#
# Processing design4_n48.pdb
# Buried Surface Area: 1408.97 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 10
# Salt Bridges: 4
#
# Processing design4_n43.pdb
# Buried Surface Area: 1861.71 Å²
# Hydrogen Bonds: 19
# Hydrophobic Contacts: 19
# Salt Bridges: 4
#
# Processing design4_n46.pdb
# Buried Surface Area: 1399.19 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design4_n41.pdb
# Buried Surface Area: 954.19 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 1
#
# Processing design4_n47.pdb
# Buried Surface Area: 1129.52 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 4
# Salt Bridges: 2
#
# Processing design4_n45.pdb
# Buried Surface Area: 1731.64 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 19
# Salt Bridges: 3
#
# Processing design4_n4.pdb
# Buried Surface Area: 1573.02 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 15
# Salt Bridges: 1
#
# Processing design4_n38.pdb
# Buried Surface Area: 1315.64 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design4_n37.pdb
# Buried Surface Area: 1275.77 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 2
# Salt Bridges: 2
#
# Processing design4_n35.pdb
# Buried Surface Area: 2024.10 Å²
# Hydrogen Bonds: 23
# Hydrophobic Contacts: 15
# Salt Bridges: 2
#
# Processing design4_n33.pdb
# Buried Surface Area: 1409.42 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 13
# Salt Bridges: 1
#
# Processing design4_n32.pdb
# Buried Surface Area: 1630.35 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 14
# Salt Bridges: 1
#
# Processing design4_n34.pdb
# Buried Surface Area: 1855.18 Å²
# Hydrogen Bonds: 12
# Hydrophobic Contacts: 8
# Salt Bridges: 0
#
# Processing design4_n39.pdb
# Buried Surface Area: 1475.05 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 17
# Salt Bridges: 0
#
# Processing design4_n36.pdb
# Buried Surface Area: 1394.42 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design4_n30.pdb
# Buried Surface Area: 1471.93 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 16
# Salt Bridges: 1
#
# Processing design4_n31.pdb
# Buried Surface Area: 1177.78 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 6
# Salt Bridges: 2
#
# Processing design4_n29.pdb
# Buried Surface Area: 2530.43 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 24
# Salt Bridges: 2
#
# Processing design4_n27.pdb
# Buried Surface Area: 1552.98 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 10
# Salt Bridges: 5
#
# Processing design4_n25.pdb
# Buried Surface Area: 1904.30 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 23
# Salt Bridges: 4
#
# Processing design4_n3.pdb
# Buried Surface Area: 1405.50 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 1
#
# Processing design4_n22.pdb
# Buried Surface Area: 1459.10 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 3
#
# Processing design4_n24.pdb
# Buried Surface Area: 2371.43 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 8
# Salt Bridges: 6
#
# Processing design4_n28.pdb
# Buried Surface Area: 1230.71 Å²
# Hydrogen Bonds: 7
# Hydrophobic Contacts: 12
# Salt Bridges: 0
#
# Processing design4_n26.pdb
# Buried Surface Area: 1675.41 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design4_n23.pdb
# Buried Surface Area: 1179.15 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design4_n21.pdb
# Buried Surface Area: 1337.06 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 0
#
# Processing design4_n2.pdb
# Buried Surface Area: 1152.74 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 5
# Salt Bridges: 4
#
# Processing design4_n15.pdb
# Buried Surface Area: 1896.07 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 21
# Salt Bridges: 1
#
# Processing design4_n18.pdb
# Buried Surface Area: 1008.49 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 11
# Salt Bridges: 0
#
# Processing design4_n16.pdb
# Buried Surface Area: 1556.31 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 9
# Salt Bridges: 0
#
# Processing design4_n17.pdb
# Buried Surface Area: 1687.75 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 26
# Salt Bridges: 1
#
# Processing design4_n20.pdb
# Buried Surface Area: 1339.94 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 1
#
# Processing design4_n19.pdb
# Buried Surface Area: 1573.38 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 16
# Salt Bridges: 4
#
# Processing design4_n12.pdb
# Buried Surface Area: 1416.15 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 8
# Salt Bridges: 2
#
# Processing design4_n14.pdb
# Buried Surface Area: 1441.87 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 3
#
# Processing design4_n13.pdb
# Buried Surface Area: 1585.92 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design4_n11.pdb
# Buried Surface Area: 1465.81 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 7
# Salt Bridges: 3
#
# Processing design4_n1.pdb
# Buried Surface Area: 2161.81 Å²
# Hydrogen Bonds: 15
# Hydrophobic Contacts: 20
# Salt Bridges: 4
#
# Processing design3_n63.pdb
# Buried Surface Area: 2551.22 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 24
# Salt Bridges: 4
#
# Processing design3_n8.pdb
# Buried Surface Area: 1264.37 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 2
# Salt Bridges: 1
#
# Processing design3_n62.pdb
# Buried Surface Area: 912.25 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 9
# Salt Bridges: 1
#
# Processing design4_n0.pdb
# Buried Surface Area: 1201.53 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 1
#
# Processing design3_n7.pdb
# Buried Surface Area: 1152.12 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design5_n62.pdb
# Buried Surface Area: 2255.04 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 23
# Salt Bridges: 1
#
# Processing design3_n9.pdb
# Buried Surface Area: 1661.64 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 13
# Salt Bridges: 5
#
# Processing design4_n10.pdb
# Buried Surface Area: 1020.86 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 5
# Salt Bridges: 2
#
# Processing design5_n57.pdb
# Buried Surface Area: 1608.10 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design5_n61.pdb
# Buried Surface Area: 1675.95 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 17
# Salt Bridges: 1
#
# Processing design5_n58.pdb
# Buried Surface Area: 2150.27 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 2
#
# Processing design5_n55.pdb
# Buried Surface Area: 2319.60 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 24
# Salt Bridges: 5
#
# Processing design5_n59.pdb
# Buried Surface Area: 1126.12 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 13
# Salt Bridges: 4
#
# Processing design5_n60.pdb
# Buried Surface Area: 1893.82 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 20
# Salt Bridges: 4
#
# Processing design5_n54.pdb
# Buried Surface Area: 1397.22 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 4
# Salt Bridges: 1
#
# Processing design5_n6.pdb
# Buried Surface Area: 1825.69 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design5_n52.pdb
# Buried Surface Area: 1521.33 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 1
#
# Processing design5_n56.pdb
# Buried Surface Area: 1543.31 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 15
# Salt Bridges: 0
#
# Processing design5_n51.pdb
# Buried Surface Area: 2000.12 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 14
# Salt Bridges: 0
#
# Processing design5_n48.pdb
# Buried Surface Area: 1806.24 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design5_n5.pdb
# Buried Surface Area: 1735.90 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design5_n49.pdb
# Buried Surface Area: 1885.37 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 4
#
# Processing design5_n47.pdb
# Buried Surface Area: 1895.61 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 3
#
# Processing design5_n50.pdb
# Buried Surface Area: 1590.15 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 2
#
# Processing design5_n53.pdb
# Buried Surface Area: 1596.30 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 1
#
# Processing design5_n45.pdb
# Buried Surface Area: 1705.41 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design5_n46.pdb
# Buried Surface Area: 1616.08 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 8
# Salt Bridges: 0
#
# Processing design5_n44.pdb
# Buried Surface Area: 1273.30 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 3
# Salt Bridges: 2
#
# Processing design5_n42.pdb
# Buried Surface Area: 1609.76 Å²
# Hydrogen Bonds: 10
# Hydrophobic Contacts: 10
# Salt Bridges: 1
#
# Processing design5_n43.pdb
# Buried Surface Area: 1406.10 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 0
#
# Processing design5_n4.pdb
# Buried Surface Area: 1527.83 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 1
#
# Processing design5_n41.pdb
# Buried Surface Area: 1928.49 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 17
# Salt Bridges: 0
#
# Processing design5_n40.pdb
# Buried Surface Area: 2006.11 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 18
# Salt Bridges: 1
#
# Processing design5_n37.pdb
# Buried Surface Area: 1610.22 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 5
# Salt Bridges: 0
#
# Processing design5_n36.pdb
# Buried Surface Area: 1264.15 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 14
# Salt Bridges: 0
#
# Processing design5_n39.pdb
# Buried Surface Area: 1289.19 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 1
#
# Processing design5_n38.pdb
# Buried Surface Area: 1512.56 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 1
#
# Processing design5_n32.pdb
# Buried Surface Area: 1393.07 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 12
# Salt Bridges: 1
#
# Processing design5_n30.pdb
# Buried Surface Area: 1550.40 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 5
# Salt Bridges: 3
#
# Processing design5_n3.pdb
# Buried Surface Area: 2201.76 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design5_n31.pdb
# Buried Surface Area: 1534.59 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 16
# Salt Bridges: 1
#
# Processing design5_n35.pdb
# Buried Surface Area: 1378.57 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 6
# Salt Bridges: 1
#
# Processing design5_n34.pdb
# Buried Surface Area: 1365.23 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 12
# Salt Bridges: 3
#
# Processing design5_n33.pdb
# Buried Surface Area: 525.84 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 1
# Salt Bridges: 0
#
# Processing design5_n28.pdb
# Buried Surface Area: 1972.56 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 13
# Salt Bridges: 2
#
# Processing design5_n29.pdb
# Buried Surface Area: 1999.63 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 20
# Salt Bridges: 1
#
# Processing design5_n27.pdb
# Buried Surface Area: 1642.76 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design5_n21.pdb
# Buried Surface Area: 1968.26 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 8
# Salt Bridges: 1
#
# Processing design5_n2.pdb
# Buried Surface Area: 2137.25 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 22
# Salt Bridges: 3
#
# Processing design5_n19.pdb
# Buried Surface Area: 1751.57 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 8
# Salt Bridges: 0
#
# Processing design5_n26.pdb
# Buried Surface Area: 1536.42 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 10
# Salt Bridges: 0
#
# Processing design5_n20.pdb
# Buried Surface Area: 1842.30 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 13
# Salt Bridges: 3
#
# Processing design5_n23.pdb
# Buried Surface Area: 1178.72 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 2
# Salt Bridges: 3
#
# Processing design5_n24.pdb
# Buried Surface Area: 2011.86 Å²
# Hydrogen Bonds: 10
# Hydrophobic Contacts: 14
# Salt Bridges: 4
#
# Processing design5_n22.pdb
# Buried Surface Area: 1317.74 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 0
#
# Processing design5_n25.pdb
# Buried Surface Area: 2057.14 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 18
# Salt Bridges: 3
#
# Processing design5_n18.pdb
# Buried Surface Area: 1703.44 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 24
# Salt Bridges: 1
#
# Processing design5_n14.pdb
# Buried Surface Area: 1311.98 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 5
# Salt Bridges: 0
#
# Processing design5_n12.pdb
# Buried Surface Area: 2891.24 Å²
# Hydrogen Bonds: 2
# Hydrophobic Contacts: 22
# Salt Bridges: 6
#
# Processing design5_n1.pdb
# Buried Surface Area: 1453.19 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 12
# Salt Bridges: 3
#
# Processing design5_n11.pdb
# Buried Surface Area: 2285.82 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 14
# Salt Bridges: 4
#
# Processing design5_n17.pdb
# Buried Surface Area: 1883.59 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design5_n16.pdb
# Buried Surface Area: 1780.27 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 16
# Salt Bridges: 2
#
# Processing design5_n13.pdb
# Buried Surface Area: 1222.11 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 5
# Salt Bridges: 1
#
# Processing design5_n15.pdb
# Buried Surface Area: 2202.98 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 16
# Salt Bridges: 4
#
# Processing design5_n0.pdb
# Buried Surface Area: 1533.66 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 1
#
# Processing design5_n10.pdb
# Buried Surface Area: 1372.05 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 3
#
# Processing design4_n8.pdb
# Buried Surface Area: 989.54 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 4
# Salt Bridges: 3
#
# Processing design4_n63.pdb
# Buried Surface Area: 1848.78 Å²
# Hydrogen Bonds: 17
# Hydrophobic Contacts: 15
# Salt Bridges: 4
#
# Processing design4_n61.pdb
# Buried Surface Area: 869.72 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 4
# Salt Bridges: 0
#
# Processing design7_n37.pdb
# Buried Surface Area: 1311.93 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 11
# Salt Bridges: 0
#
# Processing design4_n60.pdb
# Buried Surface Area: 1542.36 Å²
# Hydrogen Bonds: 14
# Hydrophobic Contacts: 6
# Salt Bridges: 6
#
# Processing design7_n34.pdb
# Buried Surface Area: 1604.52 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 12
# Salt Bridges: 0
#
# Processing design7_n36.pdb
# Buried Surface Area: 1710.70 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 6
# Salt Bridges: 3
#
# Processing design7_n35.pdb
# Buried Surface Area: 1244.38 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 9
# Salt Bridges: 2
#
# Processing design7_n33.pdb
# Buried Surface Area: 1545.71 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 2
#
# Processing design7_n3.pdb
# Buried Surface Area: 1485.82 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 4
# Salt Bridges: 2
#
# Processing design7_n32.pdb
# Buried Surface Area: 1306.44 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 5
# Salt Bridges: 1
#
# Processing design7_n30.pdb
# Buried Surface Area: 1361.36 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 11
# Salt Bridges: 4
#
# Processing design7_n31.pdb
# Buried Surface Area: 2353.52 Å²
# Hydrogen Bonds: 9
# Hydrophobic Contacts: 29
# Salt Bridges: 3
#
# Processing design7_n29.pdb
# Buried Surface Area: 1795.48 Å²
# Hydrogen Bonds: 5
# Hydrophobic Contacts: 14
# Salt Bridges: 2
#
# Processing design7_n24.pdb
# Buried Surface Area: 1219.43 Å²
# Hydrogen Bonds: 8
# Hydrophobic Contacts: 9
# Salt Bridges: 3
#
# Processing design7_n21.pdb
# Buried Surface Area: 1158.87 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 9
# Salt Bridges: 1
#
# Processing design7_n26.pdb
# Buried Surface Area: 1212.02 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 10
# Salt Bridges: 0
#
# Processing design7_n23.pdb
# Buried Surface Area: 1594.43 Å²
# Hydrogen Bonds: 10
# Hydrophobic Contacts: 14
# Salt Bridges: 3
#
# Processing design7_n20.pdb
# Buried Surface Area: 1753.97 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 7
# Salt Bridges: 3
#
# Processing design7_n27.pdb
# Buried Surface Area: 1229.25 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 5
# Salt Bridges: 3
#
# Processing design7_n25.pdb
# Buried Surface Area: 1236.21 Å²
# Hydrogen Bonds: 4
# Hydrophobic Contacts: 11
# Salt Bridges: 0
#
# Processing design7_n22.pdb
# Buried Surface Area: 1547.35 Å²
# Hydrogen Bonds: 3
# Hydrophobic Contacts: 14
# Salt Bridges: 4
#
# Processing design7_n28.pdb
# Buried Surface Area: 1426.70 Å²
# Hydrogen Bonds: 1
# Hydrophobic Contacts: 16
# Salt Bridges: 3
#
# Processing design7_n2.pdb
# Buried Surface Area: 1167.34 Å²
# Hydrogen Bonds: 0
# Hydrophobic Contacts: 8
# Salt Bridges: 0
#
# Processing design7_n19.pdb
# Buried Surface Area: 1515.35 Å²
# Hydrogen Bonds: 6
# Hydrophobic Contacts: 19
# Salt Bridges: 2
#
# Processing design7_n11.pdb
# ...
# design5_n32.pdb                1393.07                   3            12           1
# design5_n30.pdb                1550.40                   1            5            3
# design5_n3.pdb                 2201.76                   2            13           2
# design5_n31.pdb                1534.59                   6            16           1
# design5_n35.pdb                1378.57                   0            6            1
# design5_n34.pdb                1365.23                   4            12           3
# design5_n33.pdb                525.84                    0            1            0
# design5_n28.pdb                1972.56                   1            13           2
# design5_n29.pdb                1999.63                   0            20           1
# design5_n27.pdb                1642.76                   1            9            2
# design5_n21.pdb                1968.26                   3            8            1
# design5_n2.pdb                 2137.25                   1            22           3
# design5_n19.pdb                1751.57                   3            8            0
# design5_n26.pdb                1536.42                   0            10           0
# design5_n20.pdb                1842.30                   1            13           3
# design5_n23.pdb                1178.72                   0            2            3
# design5_n24.pdb                2011.86                   10           14           4
# design5_n22.pdb                1317.74                   0            11           0
# design5_n25.pdb                2057.14                   1            18           3
# design5_n18.pdb                1703.44                   2            24           1
# design5_n14.pdb                1311.98                   6            5            0
# design5_n12.pdb                2891.24                   2            22           6
# design5_n1.pdb                 1453.19                   0            12           3
# design5_n11.pdb                2285.82                   4            14           4
# design5_n17.pdb                1883.59                   3            14           2
# design5_n16.pdb                1780.27                   0            16           2
# design5_n13.pdb                1222.11                   0            5            1
# design5_n15.pdb                2202.98                   4            16           4
# design5_n0.pdb                 1533.66                   0            8            1
# design5_n10.pdb                1372.05                   0            7            3
# design4_n8.pdb                 989.54                    3            4            3
# design4_n63.pdb                1848.78                   17           15           4
# design4_n61.pdb                869.72                    0            4            0
# design7_n37.pdb                1311.93                   0            11           0
# design4_n60.pdb                1542.36                   14           6            6
# design7_n34.pdb                1604.52                   1            12           0
# design7_n36.pdb                1710.70                   3            6            3
# design7_n35.pdb                1244.38                   0            9            2
# design7_n33.pdb                1545.71                   0            8            2
# design7_n3.pdb                 1485.82                   1            4            2
# design7_n32.pdb                1306.44                   1            5            1
# design7_n30.pdb                1361.36                   5            11           4
# design7_n31.pdb                2353.52                   9            29           3
# design7_n29.pdb                1795.48                   5            14           2
# design7_n24.pdb                1219.43                   8            9            3
# design7_n21.pdb                1158.87                   1            9            1
# design7_n26.pdb                1212.02                   1            10           0
# design7_n23.pdb                1594.43                   10           14           3
# design7_n20.pdb                1753.97                   0            7            3
# design7_n27.pdb                1229.25                   0            5            3
# design7_n25.pdb                1236.21                   4            11           0
# design7_n22.pdb                1547.35                   3            14           4
# design7_n28.pdb                1426.70                   1            16           3
# design7_n2.pdb                 1167.34                   0            8            0
# design7_n19.pdb                1515.35                   6            19           2
# design7_n11.pdb                1482.16                   0            11           2
# design7_n18.pdb                1326.78                   1            6            0
# design7_n15.pdb                1063.27                   4            7            1
# design7_n13.pdb                1623.24                   0            9            0
# design7_n16.pdb                1609.64                   0            14           1
# design7_n12.pdb                1719.81                   9            9            9
# design7_n17.pdb                1464.90                   2            14           2
# design7_n10.pdb                1193.89                   4            10           1
# design7_n1.pdb                 1401.22                   0            3            1
# design7_n14.pdb                1270.21                   0            13           2
# design6_n9.pdb                 1848.69                   2            18           2
# design6_n62.pdb                1993.11                   1            19           2
# design6_n63.pdb                1284.13                   2            7            0
# design6_n8.pdb                 1733.94                   1            18           1
# design7_n0.pdb                 1146.30                   0            11           0
# design6_n7.pdb                 1312.90                   0            21           2
# design6_n60.pdb                1138.27                   0            17           1
# design6_n61.pdb                1430.79                   0            6            2
# design6_n6.pdb                 1129.20                   0            8            0
# design6_n59.pdb                1409.98                   1            11           1
# design6_n58.pdb                1650.70                   2            9            2
# design6_n54.pdb                1443.02                   0            14           3
# design6_n56.pdb                1263.28                   0            10           0
# design6_n55.pdb                1921.13                   4            17           4
# design6_n57.pdb                1750.24                   0            14           1
# design6_n51.pdb                1807.79                   2            18           3
# design6_n50.pdb                1215.89                   1            19           1
# design6_n52.pdb                1773.20                   2            23           0
# design6_n53.pdb                1848.05                   2            22           5
# design6_n46.pdb                1648.33                   2            18           5
# design6_n49.pdb                1681.58                   2            17           2
# design6_n44.pdb                1904.03                   0            17           3
# design6_n42.pdb                1825.03                   3            20           1
# design6_n45.pdb                1531.09                   2            11           1
# design6_n47.pdb                1651.48                   0            16           5
# design6_n48.pdb                1307.20                   3            10           1
# design6_n43.pdb                1288.95                   1            14           2
# design6_n5.pdb                 1806.46                   0            15           5
# design6_n41.pdb                1849.13                   1            14           3
# design6_n4.pdb                 1900.58                   1            18           2
# design6_n36.pdb                1238.77                   2            13           1
# design6_n38.pdb                1112.90                   28           11           4
# design6_n33.pdb                1737.28                   1            18           1
# design6_n35.pdb                2055.02                   1            9            3
# design6_n34.pdb                998.20                    0            8            2
# design6_n39.pdb                1690.52                   2            17           1
# design6_n40.pdb                1906.20                   1            13           4
# design6_n37.pdb                1152.86                   4            12           0
# design6_n32.pdb                1657.44                   4            20           2
# design6_n31.pdb                1566.91                   1            13           3
# design6_n3.pdb                 1304.72                   5            15           2
# design6_n29.pdb                1420.17                   5            15           2
# design6_n28.pdb                1710.46                   0            15           2
# design6_n23.pdb                1419.62                   1            21           1
# design6_n25.pdb                1514.60                   0            16           2
# design6_n30.pdb                1867.02                   1            12           2
# design6_n27.pdb                1457.13                   1            16           0
# design6_n24.pdb                1003.96                   0            10           2
# design6_n26.pdb                1966.68                   2            16           1
# design6_n21.pdb                1849.75                   1            22           1
# design5_n8.pdb                 1824.46                   0            16           3
# design6_n19.pdb                1427.47                   5            7            1
# design5_n63.pdb                1513.57                   4            16           1
# design6_n17.pdb                1482.39                   8            14           1
# design6_n0.pdb                 1418.07                   4            14           2
# design5_n9.pdb                 1497.14                   0            6            1
# design5_n7.pdb                 2279.44                   3            18           3
# design6_n10.pdb                1319.26                   0            20           1
# design6_n12.pdb                1682.49                   1            19           1
# design6_n1.pdb                 1439.66                   11           22           3
# design6_n13.pdb                1560.49                   5            22           2
# design6_n11.pdb                1760.86                   2            14           4
# design6_n14.pdb                1575.25                   1            16           3
# design6_n2.pdb                 1845.08                   9            18           0
# design6_n16.pdb                1578.56                   0            11           2
# design6_n20.pdb                1313.26                   0            9            1
# design6_n15.pdb                1863.90                   1            11           1
# design6_n18.pdb                1059.60                   2            16           0
# design6_n22.pdb                946.97                    1            12           3
# design7_n9.pdb                 1144.92                   1            8            2
# design7_n8.pdb                 841.77                    0            4            0
# design7_n61.pdb                1897.67                   0            13           2
# design7_n6.pdb                 1103.79                   1            2            2
# design7_n58.pdb                2011.04                   0            13           2
# design7_n59.pdb                1698.21                   0            14           1
# design7_n60.pdb                1214.32                   1            10           1
# design7_n63.pdb                1582.06                   1            11           1
# design7_n62.pdb                1816.69                   0            13           4
# design7_n7.pdb                 1651.18                   1            16           2
# design7_n57.pdb                1634.94                   0            13           4
# design7_n56.pdb                1785.12                   4            13           2
# design7_n52.pdb                1506.57                   0            5            3
# design7_n55.pdb                1512.84                   1            12           3
# design7_n50.pdb                1144.15                   0            8            1
# design7_n49.pdb                1382.68                   5            11           1
# design7_n5.pdb                 1157.20                   3            10           0
# design7_n53.pdb                1458.92                   1            11           2
# design7_n54.pdb                1600.23                   3            11           2
# design7_n51.pdb                1380.87                   2            9            2
# design7_n47.pdb                2095.36                   1            16           4
# design7_n48.pdb                1338.94                   2            9            2
# design7_n45.pdb                1531.75                   3            14           2
# design7_n44.pdb                1549.59                   6            17           0
# design7_n43.pdb                1534.12                   1            15           2
# design7_n42.pdb                1181.52                   6            10           1
# design7_n39.pdb                1620.17                   0            14           3
# design7_n4.pdb                 1096.33                   1            6            1
# design7_n40.pdb                1515.43                   3            11           1
# design7_n46.pdb                1556.29                   7            16           2
# design7_n41.pdb                2020.95                   2            10           4
# design7_n38.pdb                1305.70                   0            6            1

# %%
from google.colab import drive
drive.mount('/content/drive')
