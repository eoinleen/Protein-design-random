# %% [markdown]
# <a href="https://colab.research.google.com/github/eoinleen/Protein-design-random/blob/main/20250117_pdb_param_inc_VDW_nrg_too_high.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import os
import sys
from pathlib import Path
from typing import Dict, List, Optional, Tuple, Any
from Bio import PDB
import freesasa
import numpy as np
from google.colab import drive

class StructureValidationError(Exception):
    """Custom exception for structure validation failures."""
    pass

def validate_pdb_file(file_path: str) -> bool:
    """
    Validate that a file exists and has basic PDB format.
    """
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"PDB file not found: {file_path}")

    try:
        with open(file_path, 'r') as f:
            first_line = f.readline()
            if not any(marker in first_line for marker in ['HEADER', 'ATOM', 'MODEL']):
                raise StructureValidationError(f"File does not appear to be a valid PDB: {file_path}")
    except UnicodeDecodeError:
        raise StructureValidationError(f"File is not a valid text file: {file_path}")

    return True

def safe_structure_load(parser: PDB.PDBParser, file_path: str) -> Optional[PDB.Structure]:
    """
    Safely load a PDB structure with validation.
    """
    try:
        validate_pdb_file(file_path)
        structure = parser.get_structure('protein', file_path)

        # Validate structure has at least one model and chain
        models = list(structure.get_models())
        if not models:
            raise StructureValidationError("Structure contains no models")

        chains = list(models[0].get_chains())
        if not chains:
            raise StructureValidationError("Structure contains no chains")

        return structure

    except Exception as e:
        print(f"Error loading structure {file_path}: {str(e)}")
        return None

def calculate_buried_surface_area(pdb_file: str) -> Tuple[Optional[float], Optional[Dict[str, float]]]:
    """
    Calculate buried surface area between chains in a PDB structure.
    """
    parser = PDB.PDBParser(QUIET=True)
    structure = safe_structure_load(parser, pdb_file)

    if not structure:
        return None, None

    try:
        chains = list(structure.get_chains())
        if len(chains) < 2:
            print(f"Warning: {pdb_file} has fewer than 2 chains, cannot calculate BSA")
            return None, None

        # Calculate surface area for complete structure
        combined_structure = freesasa.Structure(pdb_file)
        result = freesasa.calc(combined_structure)
        total_area = result.totalArea()

        # Calculate individual chain areas
        chain_areas: Dict[str, float] = {}
        io = PDB.PDBIO()
        temp_files: List[str] = []

        try:
            for chain in chains:
                # Create a new structure with just this chain
                new_structure = PDB.Structure.Structure('temp')
                new_model = PDB.Model.Model(0)
                new_structure.add(new_model)
                new_chain = chain.copy()
                new_model.add(new_chain)

                # Save temporary file
                temp_file = f"temp_chain_{chain.id}.pdb"
                temp_files.append(temp_file)
                io.set_structure(new_structure)
                io.save(temp_file)

                # Calculate area
                chain_structure = freesasa.Structure(temp_file)
                chain_result = freesasa.calc(chain_structure)
                chain_areas[chain.id] = chain_result.totalArea()

        finally:
            # Clean up temp files
            for temp_file in temp_files:
                try:
                    if os.path.exists(temp_file):
                        os.remove(temp_file)
                except Exception as e:
                    print(f"Warning: Failed to remove temporary file {temp_file}: {str(e)}")

        # Calculate buried surface area
        total_individual_area = sum(chain_areas.values())
        buried_surface_area = abs(total_individual_area - total_area)

        return buried_surface_area, chain_areas

    except Exception as e:
        print(f"Error calculating buried surface area for {pdb_file}: {str(e)}")
        return None, None

def calculate_vdw_energy(structure: PDB.Structure) -> Optional[float]:
    """
    Calculate van der Waals energy between chains in the structure, explicitly in kcal/mol.
    """
    try:
        epsilon = 0.1  # kcal/mol
        sigma = 3.4    # Angstroms

        vdw_energy = 0.0
        chains = list(structure.get_chains())

        # Calculate VDW energy between all chain pairs
        for i, chain1 in enumerate(chains):
            for chain2 in chains[i+1:]:  # Only calculate each pair once
                atoms1 = [atom for atom in chain1.get_atoms()]
                atoms2 = [atom for atom in chain2.get_atoms()]

                for atom1 in atoms1:
                    for atom2 in atoms2:
                        try:
                            distance = np.linalg.norm(atom1.coord - atom2.coord)
                            if distance > 0 and distance < 10.0:  # Only consider interactions within 10Å
                                vdw_energy += 4 * epsilon * ((sigma / distance)**12 - (sigma / distance)**6)
                        except Exception as e:
                            print(f"Warning: Error calculating VDW interaction: {str(e)}")
                            continue

        print(f"Van der Waals energy: {vdw_energy:.2f} kcal/mol")  # Explicit output in kcal/mol
        return vdw_energy

    except Exception as e:
        print(f"Error calculating VDW energy: {str(e)}")
        return None

def calculate_hydrogen_bonds(structure: PDB.Structure) -> int:
    """
    Calculate hydrogen bonds between chains using distance and angle criteria.
    """
    try:
        h_bonds = []
        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id != chain2.id:
                    for res1 in chain1.get_residues():
                        if not is_aa(res1):
                            continue
                        for res2 in chain2.get_residues():
                            if not is_aa(res2):
                                continue
                            try:
                                # Check for backbone-backbone H-bonds
                                if 'O' in res1 and 'N' in res2:
                                    distance = res1['O'] - res2['N']
                                    if distance < 3.5:  # Standard H-bond distance cutoff
                                        h_bonds.append((res1, res2))
                            except KeyError:
                                continue  # Skip if atoms not found
        return len(h_bonds)
    except Exception as e:
        print(f"Error calculating hydrogen bonds: {str(e)}")
        return 0

def calculate_hydrophobic_contacts(structure: PDB.Structure) -> int:
    """
    Calculate hydrophobic contacts between chains.
    """
    try:
        hydrophobic_residues = {'ALA', 'VAL', 'LEU', 'ILE', 'MET', 'PHE', 'TRP', 'PRO'}
        contacts = []

        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue

                for res1 in chain1.get_residues():
                    if not is_aa(res1) or res1.get_resname() not in hydrophobic_residues:
                        continue

                    for res2 in chain2.get_residues():
                        if not is_aa(res2) or res2.get_resname() not in hydrophobic_residues:
                            continue

                        try:
                            min_distance = float('inf')
                            for atom1 in res1.get_atoms():
                                for atom2 in res2.get_atoms():
                                    distance = atom1 - atom2
                                    min_distance = min(min_distance, distance)

                            if min_distance < 5.0:
                                contacts.append((res1, res2))
                        except Exception:
                            continue

        return len(contacts)
    except Exception as e:
        print(f"Error calculating hydrophobic contacts: {str(e)}")
        return 0

def calculate_salt_bridges(structure: PDB.Structure) -> int:
    """
    Calculate salt bridges between chains.
    """
    try:
        acidic = {'ASP', 'GLU'}
        basic = {'LYS', 'ARG', 'HIS'}
        salt_bridges = []

        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue

                for res1 in chain1.get_residues():
                    if not is_aa(res1):
                        continue
                    res1_name = res1.get_resname()

                    for res2 in chain2.get_residues():
                        if not is_aa(res2):
                            continue
                        res2_name = res2.get_resname()

                        if (res1_name in acidic and res2_name in basic) or \
                           (res1_name in basic and res2_name in acidic):
                            try:
                                min_distance = float('inf')
                                for atom1 in res1.get_atoms():
                                    for atom2 in res2.get_atoms():
                                        distance = atom1 - atom2
                                        min_distance = min(min_distance, distance)

                                if min_distance < 4.0:
                                    salt_bridges.append((res1, res2))
                            except Exception:
                                continue

        return len(salt_bridges)
    except Exception as e:
        print(f"Error calculating salt bridges: {str(e)}")
        return 0

def print_summary_report(results: List[Dict[str, Any]]) -> None:
    """
    Print a formatted summary report of all results.
    """
    if not results:
        print("No results to display")
        return

    print("\nSummary Report:")
    print(f"{'PDB File':<30} {'Buried Surface Area (Å²)':<25} {'H-Bonds':<12} {'Hydrophobic':<12} {'Salt Bridges':<12} {'VDW Energy (kcal/mol)':<12}")
    print("="*100)

    for result in results:
        try:
            bsa = f"{result['buried_surface_area']:.2f}" if result['buried_surface_area'] else "N/A"
            vdw = f"{result['vdw_energy']:.2f}" if result['vdw_energy'] else "N/A"
            print(f"{result['file_name']:<30} {bsa:<25} {result['hydrogen_bonds']:<12} "
                  f"{result['hydrophobic_contacts']:<12} {result['salt_bridges']:<12} {vdw:<12}")
        except KeyError as e:
            print(f"Error displaying result for {result.get('file_name', 'unknown')}: Missing data {str(e)}")

def process_multiple_pdb_files(pdb_directory: str) -> List[Dict[str, Any]]:
    """
    Process multiple PDB files and analyze their structures.
    """
    if not os.path.exists(pdb_directory):
        raise FileNotFoundError(f"Directory not found: {pdb_directory}")

    results = []
    parser = PDB.PDBParser(QUIET=True)

    # Get list of PDB files
    pdb_files = [f for f in os.listdir(pdb_directory) if f.endswith('.pdb')]
    if not pdb_files:
        print(f"Warning: No PDB files found in {pdb_directory}")
        return results

    for file_name in pdb_files:
        pdb_file = os.path.join(pdb_directory, file_name)
        print(f"\nProcessing {file_name}")

        try:
            structure = safe_structure_load(parser, pdb_file)
            if not structure:
                continue

            buried_surface_area, chain_areas = calculate_buried_surface_area(pdb_file)
            vdw_energy = calculate_vdw_energy(structure)
            h_bonds = calculate_hydrogen_bonds(structure)
            hydrophobic = calculate_hydrophobic_contacts(structure)
            salt_bridges = calculate_salt_bridges(structure)

            results.append({
                'file_name': file_name,
                'buried_surface_area': buried_surface_area,
                'vdw_energy': vdw_energy,
                'hydrogen_bonds': h_bonds,
                'hydrophobic_contacts': hydrophobic,
                'salt_bridges': salt_bridges,
                'chain_areas': chain_areas
            })

        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}")
            continue

    return results

# Main execution
try:
    drive.mount('/content/drive')

    pdb_directory = '/content/drive/MyDrive/PDB-files/all_pdb-2MBO-no-hot'

    print("Starting analysis...")
    results = process_multiple_pdb_files(pdb_directory)

    if results:
        print_summary_report(results)
    else:
        print("No results to display")

except Exception as e:
    print(f"Fatal error: {str(e)}")
    sys.exit(1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting analysis...
#
# Processing design0_n16.pdb
# Van der Waals energy: 197353922.33 kcal/mol
#
# Processing design0_n1.pdb
# Van der Waals energy: 106546551.24 kcal/mol
#
# Processing design0_n13.pdb
# Van der Waals energy: 4525192545.27 kcal/mol
#
# Processing design0_n10.pdb
# Van der Waals energy: 1710704.96 kcal/mol
#
# Processing design0_n12.pdb
# Van der Waals energy: 758596.49 kcal/mol
#
# Processing design0_n15.pdb
# Van der Waals energy: 53091.06 kcal/mol
#
# Processing design1_n1.pdb
# Van der Waals energy: 1983392428.93 kcal/mol
#
# Processing design0_n0.pdb
# Van der Waals energy: 628830.78 kcal/mol
#
# Processing design1_n11.pdb
# Van der Waals energy: 2378412308962.11 kcal/mol
#
# Processing design0_n14.pdb
# Van der Waals energy: 611.03 kcal/mol
#
# Processing design0_n9.pdb
# Van der Waals energy: 1262.17 kcal/mol
#
# Processing design0_n11.pdb
# Van der Waals energy: 43594474026.28 kcal/mol
#
# Processing design1_n0.pdb
# Van der Waals energy: 4981.34 kcal/mol
#
# Processing design1_n12.pdb
# Van der Waals energy: 2546535340.15 kcal/mol
#
# Processing design0_n8.pdb
# Van der Waals energy: 4782172453.66 kcal/mol
#
# Processing design0_n63.pdb
# Van der Waals energy: 202964999.88 kcal/mol
#
# Processing design1_n10.pdb
# Van der Waals energy: 7874346844.62 kcal/mol
#
# Processing design0_n7.pdb
# Van der Waals energy: 53946903.15 kcal/mol
#
# Processing design0_n62.pdb
# Van der Waals energy: 174983.95 kcal/mol
#
# Processing design0_n6.pdb
# Van der Waals energy: 30656.12 kcal/mol
#
# Processing design0_n60.pdb
# Van der Waals energy: 58817.09 kcal/mol
#
# Processing design0_n58.pdb
# Van der Waals energy: 272671.55 kcal/mol
#
# Processing design0_n56.pdb
# Van der Waals energy: 172395.19 kcal/mol
#
# Processing design0_n61.pdb
# Van der Waals energy: 143.92 kcal/mol
#
# Processing design0_n59.pdb
# Van der Waals energy: 1182.89 kcal/mol
#
# Processing design0_n55.pdb
# Van der Waals energy: 4415618.51 kcal/mol
#
# Processing design0_n57.pdb
# Van der Waals energy: 120189459.65 kcal/mol
#
# Processing design0_n54.pdb
# Van der Waals energy: 95251809076.88 kcal/mol
#
# Processing design0_n53.pdb
# Van der Waals energy: 117824613101.22 kcal/mol
#
# Processing design0_n51.pdb
# Van der Waals energy: 15992117818.47 kcal/mol
#
# Processing design0_n50.pdb
# Van der Waals energy: 1206303006.00 kcal/mol
#
# Processing design0_n45.pdb
# Van der Waals energy: 290.28 kcal/mol
#
# Processing design0_n48.pdb
# Van der Waals energy: 21186496.70 kcal/mol
#
# Processing design0_n47.pdb
# Van der Waals energy: 32.28 kcal/mol
#
# Processing design0_n5.pdb
# Van der Waals energy: 22280183540.04 kcal/mol
#
# Processing design0_n52.pdb
# Van der Waals energy: 3341113.67 kcal/mol
#
# Processing design0_n49.pdb
# Van der Waals energy: 16368323.62 kcal/mol
#
# Processing design0_n46.pdb
# Van der Waals energy: 44718717019.36 kcal/mol
#
# Processing design0_n42.pdb
# Van der Waals energy: 502700.10 kcal/mol
#
# Processing design0_n40.pdb
# Van der Waals energy: 327386714625.55 kcal/mol
#
# Processing design0_n39.pdb
# Van der Waals energy: 41291248.42 kcal/mol
#
# Processing design0_n43.pdb
# Van der Waals energy: 180272.26 kcal/mol
#
# Processing design0_n41.pdb
# Van der Waals energy: 470205.49 kcal/mol
#
# Processing design0_n38.pdb
# Van der Waals energy: 11649950.34 kcal/mol
#
# Processing design0_n4.pdb
# Van der Waals energy: 6081.13 kcal/mol
#
# Processing design0_n44.pdb
# Van der Waals energy: 580253075.54 kcal/mol
#
# Processing design0_n37.pdb
# Van der Waals energy: 406790.45 kcal/mol
#
# Processing design0_n36.pdb
# Van der Waals energy: 38220416587.89 kcal/mol
#
# Processing design0_n34.pdb
# Van der Waals energy: 53573496874.77 kcal/mol
#
# Processing design0_n30.pdb
# Van der Waals energy: 1717201.42 kcal/mol
#
# Processing design0_n3.pdb
# Van der Waals energy: 71926.84 kcal/mol
#
# Processing design0_n27.pdb
# Van der Waals energy: 32971.46 kcal/mol
#
# Processing design0_n32.pdb
# Van der Waals energy: 42222893.89 kcal/mol
#
# Processing design0_n35.pdb
# Van der Waals energy: 2219.74 kcal/mol
#
# Processing design0_n33.pdb
# Van der Waals energy: 13914755.45 kcal/mol
#
# Processing design0_n31.pdb
# Van der Waals energy: 235560049.60 kcal/mol
#
# Processing design0_n25.pdb
# Van der Waals energy: 350902.51 kcal/mol
#
# Processing design0_n29.pdb
# Van der Waals energy: 1993678.74 kcal/mol
#
# Processing design0_n28.pdb
# Van der Waals energy: 73962844415.05 kcal/mol
#
# Processing design0_n22.pdb
# Van der Waals energy: 837.99 kcal/mol
#
# Processing design0_n21.pdb
# Van der Waals energy: 7795892.88 kcal/mol
#
# Processing design0_n19.pdb
# Van der Waals energy: 48633.76 kcal/mol
#
# Processing design0_n20.pdb
# Van der Waals energy: 662536.69 kcal/mol
#
# Processing design0_n26.pdb
# Van der Waals energy: 25067.80 kcal/mol
#
# Processing design0_n2.pdb
# Van der Waals energy: 1261894.18 kcal/mol
#
# Processing design0_n23.pdb
# Van der Waals energy: 13482.60 kcal/mol
#
# Processing design0_n24.pdb
# Van der Waals energy: 1584099.07 kcal/mol
#
# Processing design0_n18.pdb
# Van der Waals energy: 1399978112.89 kcal/mol
#
# Processing design0_n17.pdb
# Van der Waals energy: 7843328.33 kcal/mol
#
# Processing design1_n14.pdb
# Van der Waals energy: 97775496.27 kcal/mol
#
# Processing design1_n13.pdb
# Van der Waals energy: 382371557697.71 kcal/mol
#
# Processing design1_n19.pdb
# Van der Waals energy: 7631783233910.84 kcal/mol
#
# Processing design2_n1.pdb
# Van der Waals energy: 15557170662.77 kcal/mol
#
# Processing design1_n8.pdb
# Van der Waals energy: 19590760.95 kcal/mol
#
# Processing design2_n0.pdb
# Van der Waals energy: 90208.38 kcal/mol
#
# Processing design1_n61.pdb
# Van der Waals energy: 2198441357380393.75 kcal/mol
#
# Processing design1_n62.pdb
# Van der Waals energy: 10477740.30 kcal/mol
#
# Processing design1_n9.pdb
# Van der Waals energy: 414069054162462.56 kcal/mol
#
# Processing design1_n7.pdb
# Van der Waals energy: 68904345.29 kcal/mol
#
# Processing design1_n63.pdb
# Van der Waals energy: 66614.24 kcal/mol
#
# Processing design1_n60.pdb
# Van der Waals energy: 1080746707.68 kcal/mol
#
# Processing design1_n6.pdb
# Van der Waals energy: 1129084836.58 kcal/mol
#
# Processing design1_n58.pdb
# Van der Waals energy: 40546.17 kcal/mol
#
# Processing design1_n56.pdb
# Van der Waals energy: 1277670.42 kcal/mol
#
# Processing design1_n54.pdb
# Van der Waals energy: 365011.87 kcal/mol
#
# Processing design1_n55.pdb
# Van der Waals energy: 441157.59 kcal/mol
#
# Processing design1_n51.pdb
# Van der Waals energy: 65478841.74 kcal/mol
#
# Processing design1_n57.pdb
# Van der Waals energy: 509919040.42 kcal/mol
#
# Processing design1_n53.pdb
# Van der Waals energy: 213834562201934.81 kcal/mol
#
# Processing design1_n52.pdb
# Van der Waals energy: 353327.13 kcal/mol
#
# Processing design1_n59.pdb
# Van der Waals energy: 7971139632.35 kcal/mol
#
# Processing design1_n50.pdb
# Van der Waals energy: 130125.26 kcal/mol
#
# Processing design1_n49.pdb
# Van der Waals energy: 19644981.26 kcal/mol
#
# Processing design1_n47.pdb
# Van der Waals energy: 3912655.36 kcal/mol
#
# Processing design1_n44.pdb
# Van der Waals energy: 10632.56 kcal/mol
#
# Processing design1_n48.pdb
# Van der Waals energy: 2856091.86 kcal/mol
#
# Processing design1_n43.pdb
# Van der Waals energy: 538411942.02 kcal/mol
#
# Processing design1_n5.pdb
# Van der Waals energy: 1802944.20 kcal/mol
#
# Processing design1_n42.pdb
# Van der Waals energy: 19798129730.62 kcal/mol
#
# Processing design1_n45.pdb
# Van der Waals energy: 345560379.44 kcal/mol
#
# Processing design1_n46.pdb
# Van der Waals energy: 124331.73 kcal/mol
#
# Processing design1_n41.pdb
# Van der Waals energy: 18062584.00 kcal/mol
#
# Processing design1_n4.pdb
# Van der Waals energy: 790563476.40 kcal/mol
#
# Processing design1_n37.pdb
# Van der Waals energy: 1665897255.63 kcal/mol
#
# Processing design1_n39.pdb
# Van der Waals energy: 26650819.14 kcal/mol
#
# Processing design1_n33.pdb
# Van der Waals energy: 161452041.55 kcal/mol
#
# Processing design1_n35.pdb
# Van der Waals energy: 82293.11 kcal/mol
#
# Processing design1_n40.pdb
# Van der Waals energy: 365399.65 kcal/mol
#
# Processing design1_n36.pdb
# Van der Waals energy: 15153379.85 kcal/mol
#
# Processing design1_n24.pdb
# Van der Waals energy: 875560409.70 kcal/mol
#
# Processing design1_n21.pdb
# Van der Waals energy: 6460096078.58 kcal/mol
#
# Processing design1_n25.pdb
# Van der Waals energy: 215295.78 kcal/mol
#
# Processing design1_n28.pdb
# Van der Waals energy: 773241608.52 kcal/mol
#
# Processing design1_n23.pdb
# Van der Waals energy: 17465830.41 kcal/mol
#
# Processing design1_n26.pdb
# Van der Waals energy: 15541.16 kcal/mol
#
# Processing design1_n29.pdb
# Van der Waals energy: 53468603402.63 kcal/mol
#
# Processing design1_n30.pdb
# Van der Waals energy: 8402.60 kcal/mol
#
# Processing design1_n3.pdb
# Van der Waals energy: 2126405162.86 kcal/mol
#
# Processing design1_n27.pdb
# Van der Waals energy: 9991624.71 kcal/mol
#
# Processing design1_n31.pdb
# Van der Waals energy: 19222.86 kcal/mol
#
# Processing design1_n32.pdb
# Van der Waals energy: 6444.73 kcal/mol
#
# Processing design1_n2.pdb
# Van der Waals energy: 124142337.82 kcal/mol
#
# Processing design1_n34.pdb
# Van der Waals energy: 217703718.94 kcal/mol
#
# Processing design1_n38.pdb
# Van der Waals energy: 8479.08 kcal/mol
#
# Processing design1_n22.pdb
# Van der Waals energy: 43798921841.32 kcal/mol
#
# Processing design1_n16.pdb
# Van der Waals energy: 2989098804.71 kcal/mol
#
# Processing design1_n20.pdb
# Van der Waals energy: 402704138.70 kcal/mol
#
# Processing design1_n18.pdb
# Van der Waals energy: 399595.03 kcal/mol
#
# Processing design1_n15.pdb
# Van der Waals energy: 85046047.50 kcal/mol
#
# Processing design1_n17.pdb
# Van der Waals energy: 30254872969.21 kcal/mol
#
# Processing design2_n62.pdb
# Van der Waals energy: 470081.80 kcal/mol
#
# Processing design2_n63.pdb
# Van der Waals energy: 153589668.27 kcal/mol
#
# Processing design2_n58.pdb
# Van der Waals energy: 187989380.47 kcal/mol
#
# Processing design2_n60.pdb
# Van der Waals energy: 62049992.77 kcal/mol
#
# Processing design2_n57.pdb
# Van der Waals energy: 78233615974479.08 kcal/mol
#
# Processing design2_n59.pdb
# Van der Waals energy: 575023.35 kcal/mol
#
# Processing design2_n7.pdb
# Van der Waals energy: 47409615.70 kcal/mol
#
# Processing design2_n6.pdb
# Van der Waals energy: 337.71 kcal/mol
#
# Processing design2_n61.pdb
# Van der Waals energy: 25464841.37 kcal/mol
#
# Processing design2_n56.pdb
# Van der Waals energy: 27222651769493.82 kcal/mol
#
# Processing design2_n54.pdb
# Van der Waals energy: 287402568.49 kcal/mol
#
# Processing design2_n53.pdb
# Van der Waals energy: 131169128749.45 kcal/mol
#
# Processing design2_n50.pdb
# Van der Waals energy: 39364290.36 kcal/mol
#
# Processing design2_n47.pdb
# Van der Waals energy: 2006204203.34 kcal/mol
#
# Processing design2_n5.pdb
# Van der Waals energy: 1336803.73 kcal/mol
#
# Processing design2_n52.pdb
# Van der Waals energy: 173829411.60 kcal/mol
#
# Processing design2_n49.pdb
# Van der Waals energy: 15767913.78 kcal/mol
#
# Processing design2_n55.pdb
# Van der Waals energy: 47147876.83 kcal/mol
#
# Processing design2_n51.pdb
# Van der Waals energy: 3279896.16 kcal/mol
#
# Processing design2_n48.pdb
# Van der Waals energy: 122310396.59 kcal/mol
#
# Processing design2_n43.pdb
# Van der Waals energy: 706939983.27 kcal/mol
#
# Processing design2_n46.pdb
# Van der Waals energy: 16648722.98 kcal/mol
#
# Processing design2_n41.pdb
# Van der Waals energy: 47706371680393.64 kcal/mol
#
# Processing design2_n42.pdb
# Van der Waals energy: 51672027724.79 kcal/mol
#
# Processing design2_n45.pdb
# Van der Waals energy: 605710339.09 kcal/mol
#
# Processing design2_n39.pdb
# Van der Waals energy: -4.41 kcal/mol
#
# Processing design2_n4.pdb
# Van der Waals energy: 4268.60 kcal/mol
#
# Processing design2_n44.pdb
# Van der Waals energy: 38834635.78 kcal/mol
#
# Processing design2_n40.pdb
# Van der Waals energy: 13766.50 kcal/mol
#
# Processing design2_n38.pdb
# Van der Waals energy: 12683265712.75 kcal/mol
#
# Processing design2_n28.pdb
# Van der Waals energy: 3357756.34 kcal/mol
#
# Processing design2_n31.pdb
# Van der Waals energy: 1166850.63 kcal/mol
#
# Processing design2_n34.pdb
# Van der Waals energy: 112382.89 kcal/mol
#
# Processing design2_n29.pdb
# Van der Waals energy: 2812635.09 kcal/mol
#
# Processing design2_n33.pdb
# Van der Waals energy: 979055.66 kcal/mol
#
# Processing design2_n35.pdb
# Van der Waals energy: 713595221425.37 kcal/mol
#
# Processing design2_n3.pdb
# Van der Waals energy: 1097.55 kcal/mol
#
# Processing design2_n30.pdb
# Van der Waals energy: 2094491472863.18 kcal/mol
#
# Processing design2_n32.pdb
# Van der Waals energy: 760125091.72 kcal/mol
#
# Processing design2_n36.pdb
# Van der Waals energy: 28763.03 kcal/mol
#
# Processing design2_n25.pdb
# Van der Waals energy: 8918147282.94 kcal/mol
#
# Processing design2_n37.pdb
# Van der Waals energy: 11986301.83 kcal/mol
#
# Processing design2_n24.pdb
# Van der Waals energy: 6773636026.05 kcal/mol
#
# Processing design2_n22.pdb
# Van der Waals energy: 133971087932.63 kcal/mol
#
# Processing design2_n27.pdb
# Van der Waals energy: 243941761.21 kcal/mol
#
# Processing design2_n23.pdb
# Van der Waals energy: 93861.77 kcal/mol
#
# Processing design2_n21.pdb
# Van der Waals energy: 2547849791.96 kcal/mol
#
# Processing design2_n20.pdb
# Van der Waals energy: 240472957384.88 kcal/mol
#
# Processing design2_n26.pdb
# Van der Waals energy: 1247377.31 kcal/mol
#
# Processing design2_n2.pdb
# Van der Waals energy: 53657228.52 kcal/mol
#
# Processing design2_n18.pdb
# Van der Waals energy: 6436559.39 kcal/mol
#
# Processing design2_n17.pdb
# Van der Waals energy: 1173853242.13 kcal/mol
#
# Processing design2_n13.pdb
# Van der Waals energy: 4155113960.91 kcal/mol
#
# Processing design2_n16.pdb
# Van der Waals energy: 93243685.76 kcal/mol
#
# Processing design2_n11.pdb
# Van der Waals energy: 427500936.65 kcal/mol
#
# Processing design2_n12.pdb
# Van der Waals energy: 845752312.57 kcal/mol
#
# Processing design2_n19.pdb
# Van der Waals energy: 14802904552.04 kcal/mol
#
# Processing design2_n14.pdb
# Van der Waals energy: 1585810.23 kcal/mol
#
# Processing design2_n15.pdb
# Van der Waals energy: 2302214812.59 kcal/mol
#
# Processing design2_n10.pdb
# Van der Waals energy: 28225782216705.03 kcal/mol
#
# Processing design3_n61.pdb
# Van der Waals energy: 37131697829.71 kcal/mol
#
# Processing design3_n60.pdb
# Van der Waals energy: 1900.26 kcal/mol
#
# Processing design3_n6.pdb
# Van der Waals energy: 1309054.04 kcal/mol
#
# Processing design3_n57.pdb
# Van der Waals energy: 2120.62 kcal/mol
#
# Processing design3_n56.pdb
# Van der Waals energy: 795.06 kcal/mol
#
# Processing design3_n58.pdb
# Van der Waals energy: 90665421150.24 kcal/mol
#
# Processing design3_n54.pdb
# Van der Waals energy: 76841353.11 kcal/mol
#
# Processing design3_n59.pdb
# Van der Waals energy: 306955047.93 kcal/mol
#
# Processing design3_n53.pdb
# Van der Waals energy: 10259559.76 kcal/mol
#
# Processing design3_n51.pdb
# Van der Waals energy: 2712977648.85 kcal/mol
#
# Processing design3_n52.pdb
# Van der Waals energy: 29244832.28 kcal/mol
#
# Processing design3_n55.pdb
# Van der Waals energy: 37174.66 kcal/mol
#
# Processing design3_n48.pdb
# Van der Waals energy: 355851219.10 kcal/mol
#
# Processing design3_n49.pdb
# Van der Waals energy: 910787879992.67 kcal/mol
#
# Processing design3_n45.pdb
# Van der Waals energy: 31590.38 kcal/mol
#
# Processing design3_n5.pdb
# Van der Waals energy: 109354261799.15 kcal/mol
#
# Processing design3_n50.pdb
# Van der Waals energy: 5381694622.79 kcal/mol
#
# Processing design3_n43.pdb
# Van der Waals energy: 23213002793.10 kcal/mol
#
# Processing design3_n46.pdb
# Van der Waals energy: 12343267.40 kcal/mol
#
# Processing design3_n47.pdb
# Van der Waals energy: 2353032972.50 kcal/mol
#
# Processing design3_n44.pdb
# Van der Waals energy: 15890134041.45 kcal/mol
#
# Processing design3_n42.pdb
# Van der Waals energy: 6855931645907.85 kcal/mol
#
# Processing design3_n41.pdb
# Van der Waals energy: 241285576.19 kcal/mol
#
# Processing design3_n39.pdb
# Van der Waals energy: 30893623580.10 kcal/mol
#
# Processing design3_n38.pdb
# Van der Waals energy: 185785280983.82 kcal/mol
#
# Processing design3_n37.pdb
# Van der Waals energy: 166801682546.59 kcal/mol
#
# Processing design3_n35.pdb
# Van der Waals energy: 1346077.27 kcal/mol
#
# Processing design3_n40.pdb
# Van der Waals energy: 266440.01 kcal/mol
#
# Processing design3_n4.pdb
# Van der Waals energy: 1284844382.73 kcal/mol
#
# Processing design3_n36.pdb
# Van der Waals energy: 765563455856.59 kcal/mol
#
# Processing design3_n34.pdb
# Van der Waals energy: 187.49 kcal/mol
#
# Processing design3_n32.pdb
# Van der Waals energy: 63999.87 kcal/mol
#
# Processing design3_n30.pdb
# Van der Waals energy: 809463176469.12 kcal/mol
#
# Processing design3_n31.pdb
# Van der Waals energy: 149174911.59 kcal/mol
#
# Processing design3_n3.pdb
# Van der Waals energy: 2537714027.58 kcal/mol
#
# Processing design3_n27.pdb
# Van der Waals energy: 9490947841.23 kcal/mol
#
# Processing design3_n28.pdb
# Van der Waals energy: 9.51 kcal/mol
#
# Processing design3_n33.pdb
# Van der Waals energy: 616.78 kcal/mol
#
# Processing design3_n25.pdb
# Van der Waals energy: 46469714.03 kcal/mol
#
# Processing design3_n26.pdb
# Van der Waals energy: 5722.69 kcal/mol
#
# Processing design3_n29.pdb
# Van der Waals energy: 2103879.20 kcal/mol
#
# Processing design3_n23.pdb
# Van der Waals energy: 82927.98 kcal/mol
#
# Processing design3_n21.pdb
# Van der Waals energy: 641175225.81 kcal/mol
#
# Processing design3_n20.pdb
# Van der Waals energy: 47000.44 kcal/mol
#
# Processing design2_n8.pdb
# Van der Waals energy: 71134520893.30 kcal/mol
#
# Processing design3_n19.pdb
# Van der Waals energy: 35275200351.87 kcal/mol
#
# Processing design3_n1.pdb
# Van der Waals energy: 68269.88 kcal/mol
#
# Processing design3_n11.pdb
# Van der Waals energy: 16148713978.09 kcal/mol
#
# Processing design3_n14.pdb
# Van der Waals energy: 36054.30 kcal/mol
#
# Processing design2_n9.pdb
# Van der Waals energy: 498069.97 kcal/mol
#
# Processing design3_n12.pdb
# Van der Waals energy: 2915.75 kcal/mol
#
# Processing design3_n10.pdb
# Van der Waals energy: 3012179.58 kcal/mol
#
# Processing design3_n0.pdb
# Van der Waals energy: 28015516.26 kcal/mol
#
# Processing design3_n15.pdb
# Van der Waals energy: 58123293.71 kcal/mol
#
# Processing design3_n13.pdb
# Van der Waals energy: 1811820119801.59 kcal/mol
#
# Processing design3_n16.pdb
# Van der Waals energy: 32390.08 kcal/mol
#
# Processing design3_n2.pdb
# Van der Waals energy: 304068.70 kcal/mol
#
# Processing design3_n18.pdb
# Van der Waals energy: 36263143.78 kcal/mol
#
# Processing design3_n24.pdb
# Van der Waals energy: 4456331.08 kcal/mol
#
# Processing design3_n22.pdb
# Van der Waals energy: 4900242.81 kcal/mol
#
# Processing design3_n17.pdb
# Van der Waals energy: 92398597181.63 kcal/mol
#
# Processing design4_n58.pdb
# Van der Waals energy: 255082097.04 kcal/mol
#
# Processing design4_n7.pdb
# Van der Waals energy: 46223807133.51 kcal/mol
#
# Processing design4_n62.pdb
# Van der Waals energy: 205809.36 kcal/mol
#
# Processing design4_n9.pdb
# Van der Waals energy: 64830447.86 kcal/mol
#
# Processing design4_n6.pdb
# Van der Waals energy: 76929.13 kcal/mol
#
# Processing design4_n56.pdb
# Van der Waals energy: 5785029083.14 kcal/mol
#
# Processing design4_n59.pdb
# Van der Waals energy: 664447189375.78 kcal/mol
#
# Processing design4_n52.pdb
# Van der Waals energy: 150470315.28 kcal/mol
#
# Processing design4_n55.pdb
# Van der Waals energy: 1046278.60 kcal/mol
#
# Processing design4_n57.pdb
# Van der Waals energy: 406041916.78 kcal/mol
#
# Processing design4_n50.pdb
# Van der Waals energy: 8873.52 kcal/mol
#
# Processing design4_n54.pdb
# Van der Waals energy: 234840122.09 kcal/mol
#
# Processing design4_n5.pdb
# Van der Waals energy: 3261480276943.27 kcal/mol
#
# Processing design4_n53.pdb
# Van der Waals energy: 2358.56 kcal/mol
#
# Processing design4_n49.pdb
# Van der Waals energy: 694769772417.10 kcal/mol
#
# Processing design4_n51.pdb
# Van der Waals energy: 190361.84 kcal/mol
#
# Processing design4_n44.pdb
# Van der Waals energy: 648889834.04 kcal/mol
#
# Processing design4_n42.pdb
# Van der Waals energy: 3307.96 kcal/mol
#
# Processing design4_n40.pdb
# Van der Waals energy: 4411698.30 kcal/mol
#
# Processing design4_n48.pdb
# Van der Waals energy: 777785266.07 kcal/mol
#
# Processing design4_n43.pdb
# Van der Waals energy: 2144362550.04 kcal/mol
#
# Processing design4_n46.pdb
# Van der Waals energy: 5527635525.51 kcal/mol
#
# Processing design4_n41.pdb
# Van der Waals energy: 24778.04 kcal/mol
#
# Processing design4_n47.pdb
# Van der Waals energy: 2481686533425.51 kcal/mol
#
# Processing design4_n45.pdb
# Van der Waals energy: 224478631.89 kcal/mol
#
# Processing design4_n4.pdb
# Van der Waals energy: 14335651.23 kcal/mol
#
# Processing design4_n38.pdb
# Van der Waals energy: 3907794006.01 kcal/mol
#
# Processing design4_n37.pdb
# Van der Waals energy: 723449982.14 kcal/mol
#
# Processing design4_n35.pdb
# Van der Waals energy: 110725429.53 kcal/mol
#
# Processing design4_n33.pdb
# Van der Waals energy: 2486426.80 kcal/mol
#
# Processing design4_n32.pdb
# Van der Waals energy: 5955752920.01 kcal/mol
#
# Processing design4_n34.pdb
# Van der Waals energy: 3170593861.25 kcal/mol
#
# Processing design4_n39.pdb
# Van der Waals energy: 4398483.23 kcal/mol
#
# Processing design4_n36.pdb
# Van der Waals energy: 354980.97 kcal/mol
#
# Processing design4_n30.pdb
# Van der Waals energy: 232517.96 kcal/mol
#
# Processing design4_n31.pdb
# Van der Waals energy: 2831.66 kcal/mol
#
# Processing design4_n29.pdb
# Van der Waals energy: 1060694982.88 kcal/mol
#
# Processing design4_n27.pdb
# Van der Waals energy: 52112617.50 kcal/mol
#
# Processing design4_n25.pdb
# Van der Waals energy: 421099065.40 kcal/mol
#
# Processing design4_n3.pdb
# Van der Waals energy: 40324391218.33 kcal/mol
#
# Processing design4_n22.pdb
# Van der Waals energy: 49786.84 kcal/mol
#
# Processing design4_n24.pdb
# Van der Waals energy: 5496529.57 kcal/mol
#
# Processing design4_n28.pdb
# Van der Waals energy: 1909535504.55 kcal/mol
#
# Processing design4_n26.pdb
# Van der Waals energy: 262833.14 kcal/mol
#
# Processing design4_n23.pdb
# Van der Waals energy: 50872818.06 kcal/mol
#
# Processing design4_n21.pdb
# Van der Waals energy: 257640.15 kcal/mol
#
# Processing design4_n2.pdb
# Van der Waals energy: 308868.66 kcal/mol
#
# Processing design4_n15.pdb
# Van der Waals energy: 355862724.35 kcal/mol
#
# Processing design4_n18.pdb
# Van der Waals energy: 1387116.34 kcal/mol
#
# Processing design4_n16.pdb
# Van der Waals energy: 82252.86 kcal/mol
#
# Processing design4_n17.pdb
# Van der Waals energy: 40899855293.75 kcal/mol
#
# Processing design4_n20.pdb
# Van der Waals energy: 349073317.14 kcal/mol
#
# Processing design4_n19.pdb
# Van der Waals energy: 2199225544.38 kcal/mol
#
# Processing design4_n12.pdb
# Van der Waals energy: 276611824.54 kcal/mol
#
# Processing design4_n14.pdb
# Van der Waals energy: 1731234.34 kcal/mol
#
# Processing design4_n13.pdb
# Van der Waals energy: 562966736514385.88 kcal/mol
#
# Processing design4_n11.pdb
# Van der Waals energy: 538966.87 kcal/mol
#
# Processing design4_n1.pdb
# Van der Waals energy: 8980434874847.61 kcal/mol
#
# Processing design3_n63.pdb
# Van der Waals energy: 986475215.89 kcal/mol
#
# Processing design3_n8.pdb
# Van der Waals energy: 2661.18 kcal/mol
#
# Processing design3_n62.pdb
# Van der Waals energy: 410.40 kcal/mol
#
# Processing design4_n0.pdb
# Van der Waals energy: 1279079.60 kcal/mol
#
# Processing design3_n7.pdb
# Van der Waals energy: 940710214.32 kcal/mol
#
# Processing design5_n62.pdb
# Van der Waals energy: 1070.37 kcal/mol
#
# Processing design3_n9.pdb
# Van der Waals energy: 368815248845.94 kcal/mol
#
# Processing design4_n10.pdb
# Van der Waals energy: 3799.41 kcal/mol
#
# Processing design5_n57.pdb
# Van der Waals energy: 313476281.86 kcal/mol
#
# Processing design5_n61.pdb
# Van der Waals energy: 1756870.77 kcal/mol
#
# Processing design5_n58.pdb
# Van der Waals energy: 351711.73 kcal/mol
#
# Processing design5_n55.pdb
# Van der Waals energy: 475873.64 kcal/mol
#
# Processing design5_n59.pdb
# Van der Waals energy: 258724882.31 kcal/mol
#
# Processing design5_n60.pdb
# Van der Waals energy: 278900165.32 kcal/mol
#
# Processing design5_n54.pdb
# Van der Waals energy: 13801772.94 kcal/mol
#
# Processing design5_n6.pdb
# Van der Waals energy: 9199184.78 kcal/mol
#
# Processing design5_n52.pdb
# Van der Waals energy: 8685092.07 kcal/mol
#
# Processing design5_n56.pdb
# Van der Waals energy: 612763.77 kcal/mol
#
# Processing design5_n51.pdb
# Van der Waals energy: 6604.38 kcal/mol
#
# Processing design5_n48.pdb
# Van der Waals energy: 7420774.40 kcal/mol
#
# Processing design5_n5.pdb
# Van der Waals energy: 17611019.30 kcal/mol
#
# Processing design5_n49.pdb
# Van der Waals energy: 26832002849.10 kcal/mol
#
# Processing design5_n47.pdb
# Van der Waals energy: 20853803.28 kcal/mol
#
# Processing design5_n50.pdb
# Van der Waals energy: 658484.52 kcal/mol
#
# Processing design5_n53.pdb
# Van der Waals energy: 2711493.36 kcal/mol
#
# Processing design5_n45.pdb
# Van der Waals energy: 4447133.37 kcal/mol
#
# Processing design5_n46.pdb
# Van der Waals energy: 7149932.53 kcal/mol
#
# Processing design5_n44.pdb
# Van der Waals energy: 20713459.67 kcal/mol
#
# Processing design5_n42.pdb
# Van der Waals energy: 1062763543.50 kcal/mol
#
# Processing design5_n43.pdb
# Van der Waals energy: 5544161.85 kcal/mol
#
# Processing design5_n4.pdb
# Van der Waals energy: 37493.48 kcal/mol
#
# Processing design5_n41.pdb
# Van der Waals energy: 13998890087.20 kcal/mol
#
# Processing design5_n40.pdb
# Van der Waals energy: 387327414.92 kcal/mol
#
# Processing design5_n37.pdb
# Van der Waals energy: 12240.05 kcal/mol
#
# Processing design5_n36.pdb
# Van der Waals energy: 236192246654.85 kcal/mol
#
# Processing design5_n39.pdb
# Van der Waals energy: 80959408.26 kcal/mol
#
# Processing design5_n38.pdb
# Van der Waals energy: 2318.33 kcal/mol
#
# Processing design5_n32.pdb
# Van der Waals energy: 317565.74 kcal/mol
#
# Processing design5_n30.pdb
# Van der Waals energy: 139739399.57 kcal/mol
#
# Processing design5_n3.pdb
# Van der Waals energy: 1004382.50 kcal/mol
#
# Processing design5_n31.pdb
# Van der Waals energy: 65723187523609.59 kcal/mol
#
# Processing design5_n35.pdb
# Van der Waals energy: 228405.88 kcal/mol
#
# Processing design5_n34.pdb
# Van der Waals energy: 1701424.10 kcal/mol
#
# Processing design5_n33.pdb
# Van der Waals energy: 94.08 kcal/mol
#
# Processing design5_n28.pdb
# Van der Waals energy: 48517145.27 kcal/mol
#
# Processing design5_n29.pdb
# Van der Waals energy: 114296063.94 kcal/mol
#
# Processing design5_n27.pdb
# Van der Waals energy: 767662588.90 kcal/mol
#
# Processing design5_n21.pdb
# Van der Waals energy: 133641556.87 kcal/mol
#
# Processing design5_n2.pdb
# Van der Waals energy: 7483674225.42 kcal/mol
#
# Processing design5_n19.pdb
# Van der Waals energy: 68173696681.83 kcal/mol
#
# Processing design5_n26.pdb
# Van der Waals energy: 10536964.92 kcal/mol
#
# Processing design5_n20.pdb
# Van der Waals energy: 1060814660.42 kcal/mol
#
# Processing design5_n23.pdb
# Van der Waals energy: 145889899.56 kcal/mol
#
# Processing design5_n24.pdb
# Van der Waals energy: 155033690.28 kcal/mol
#
# Processing design5_n22.pdb
# Van der Waals energy: 158699.55 kcal/mol
#
# Processing design5_n25.pdb
# Van der Waals energy: 138300447.77 kcal/mol
#
# Processing design5_n18.pdb
# Van der Waals energy: 987750.12 kcal/mol
#
# Processing design5_n14.pdb
# Van der Waals energy: 5053842990.01 kcal/mol
#
# Processing design5_n12.pdb
# Van der Waals energy: 2139844264.18 kcal/mol
#
# Processing design5_n1.pdb
# Van der Waals energy: 839901762.49 kcal/mol
#
# Processing design5_n11.pdb
# Van der Waals energy: 207813967.46 kcal/mol
#
# Processing design5_n17.pdb
# Van der Waals energy: 8481250848290.71 kcal/mol
#
# Processing design5_n16.pdb
# Van der Waals energy: 1178240337079.21 kcal/mol
#
# Processing design5_n13.pdb
# Van der Waals energy: 166676209.24 kcal/mol
#
# Processing design5_n15.pdb
# Van der Waals energy: 2873854805.35 kcal/mol
#
# Processing design5_n0.pdb
# Van der Waals energy: 84036587822.62 kcal/mol
#
# Processing design5_n10.pdb
# Van der Waals energy: 125340862.50 kcal/mol
#
# Processing design4_n8.pdb
# Van der Waals energy: 1652373129.65 kcal/mol
#
# Processing design4_n63.pdb
# Van der Waals energy: 28771801026960.56 kcal/mol
#
# Processing design4_n61.pdb
# Van der Waals energy: 44720078500.29 kcal/mol
#
# Processing design7_n37.pdb
# Van der Waals energy: 441097.05 kcal/mol
#
# Processing design4_n60.pdb
# Van der Waals energy: 3924179581472.26 kcal/mol
#
# Processing design7_n34.pdb
# Van der Waals energy: 117860.75 kcal/mol
#
# Processing design7_n36.pdb
# Van der Waals energy: 547818992.69 kcal/mol
#
# Processing design7_n35.pdb
# Van der Waals energy: 1431687413.32 kcal/mol
#
# Processing design7_n33.pdb
# Van der Waals energy: 6498300564.55 kcal/mol
#
# Processing design7_n3.pdb
# Van der Waals energy: 1017.92 kcal/mol
#
# Processing design7_n32.pdb
# Van der Waals energy: 257.19 kcal/mol
#
# Processing design7_n30.pdb
# Van der Waals energy: 4592659497.43 kcal/mol
#
# Processing design7_n31.pdb
# Van der Waals energy: 2051485157657458.75 kcal/mol
#
# Processing design7_n29.pdb
# Van der Waals energy: 1464267.31 kcal/mol
#
# Processing design7_n24.pdb
# Van der Waals energy: 22058342482.59 kcal/mol
#
# Processing design7_n21.pdb
# Van der Waals energy: 2988138.81 kcal/mol
#
# Processing design7_n26.pdb
# Van der Waals energy: 1490981.94 kcal/mol
#
# Processing design7_n23.pdb
# Van der Waals energy: 630230603.25 kcal/mol
#
# Processing design7_n20.pdb
# Van der Waals energy: 1848.02 kcal/mol
#
# Processing design7_n27.pdb
# Van der Waals energy: 46787354.37 kcal/mol
#
# Processing design7_n25.pdb
# Van der Waals energy: 143053840.34 kcal/mol
#
# Processing design7_n22.pdb
# Van der Waals energy: 110761203.87 kcal/mol
#
# Processing design7_n28.pdb
# Van der Waals energy: 27990541.03 kcal/mol
#
# Processing design7_n2.pdb
# Van der Waals energy: 1130680564.03 kcal/mol
#
# Processing design7_n19.pdb
# Van der Waals energy: 694045396.19 kcal/mol
#
# Processing design7_n11.pdb
# Van der Waals energy: 675139714.48 kcal/mol
#
# Processing design7_n18.pdb
# Van der Waals energy: 1791079508.65 kcal/mol
#
# Processing design7_n15.pdb
# Van der Waals energy: 11250901294.74 kcal/mol
#
# Processing design7_n13.pdb
# Van der Waals energy: 24727.66 kcal/mol
#
# Processing design7_n16.pdb
# Van der Waals energy: 70302.24 kcal/mol
#
# Processing design7_n12.pdb
# Van der Waals energy: 1859648356.24 kcal/mol
#
# Processing design7_n17.pdb
# Van der Waals energy: 447633511.77 kcal/mol
#
# Processing design7_n10.pdb
# Van der Waals energy: 2489382.11 kcal/mol
#
# Processing design7_n1.pdb
# Van der Waals energy: 3342088174.64 kcal/mol
#
# Processing design7_n14.pdb
# Van der Waals energy: 286764.93 kcal/mol
#
# Processing design6_n9.pdb
# Van der Waals energy: 273038.81 kcal/mol
#
# Processing design6_n62.pdb
# Van der Waals energy: 12993515306.06 kcal/mol
#
# Processing design6_n63.pdb
# Van der Waals energy: 173012.41 kcal/mol
#
# Processing design6_n8.pdb
# Van der Waals energy: 28624750.63 kcal/mol
#
# Processing design7_n0.pdb
# Van der Waals energy: 52712758973.07 kcal/mol
#
# Processing design6_n7.pdb
# Van der Waals energy: 63218.71 kcal/mol
#
# Processing design6_n60.pdb
# Van der Waals energy: 2304826714.65 kcal/mol
#
# Processing design6_n61.pdb
# Van der Waals energy: 27963453822626108.00 kcal/mol
#
# Processing design6_n6.pdb
# Van der Waals energy: 22948.18 kcal/mol
#
# Processing design6_n59.pdb
# Van der Waals energy: 15727100.06 kcal/mol
#
# Processing design6_n58.pdb
# Van der Waals energy: 24445.22 kcal/mol
#
# Processing design6_n54.pdb
# Van der Waals energy: 116347.69 kcal/mol
#
# Processing design6_n56.pdb
# Van der Waals energy: 445316.22 kcal/mol
#
# Processing design6_n55.pdb
# Van der Waals energy: 9382.58 kcal/mol
#
# Processing design6_n57.pdb
# Van der Waals energy: 38387.41 kcal/mol
#
# Processing design6_n51.pdb
# Van der Waals energy: 21056.81 kcal/mol
#
# Processing design6_n50.pdb
# Van der Waals energy: 721699686.47 kcal/mol
#
# Processing design6_n52.pdb
# Van der Waals energy: 8480966.49 kcal/mol
#
# Processing design6_n53.pdb
# Van der Waals energy: 147125.76 kcal/mol
#
# Processing design6_n46.pdb
# Van der Waals energy: 37235449.49 kcal/mol
#
# Processing design6_n49.pdb
# Van der Waals energy: 278233.14 kcal/mol
#
# Processing design6_n44.pdb
# Van der Waals energy: 40419.62 kcal/mol
#
# Processing design6_n42.pdb
# Van der Waals energy: 107011106.13 kcal/mol
#
# Processing design6_n45.pdb
# Van der Waals energy: 19527386.24 kcal/mol
#
# Processing design6_n47.pdb
# Van der Waals energy: 78427.51 kcal/mol
#
# Processing design6_n48.pdb
# Van der Waals energy: 317133237.94 kcal/mol
#
# Processing design6_n43.pdb
# Van der Waals energy: 11727327.23 kcal/mol
#
# Processing design6_n5.pdb
# Van der Waals energy: 2309309.31 kcal/mol
#
# Processing design6_n41.pdb
# Van der Waals energy: 1251918.72 kcal/mol
#
# Processing design6_n4.pdb
# Van der Waals energy: 535286.34 kcal/mol
#
# Processing design6_n36.pdb
# Van der Waals energy: 85912.55 kcal/mol
#
# Processing design6_n38.pdb
# Van der Waals energy: 665437056.28 kcal/mol
#
# Processing design6_n33.pdb
# Van der Waals energy: 70167059.33 kcal/mol
#
# Processing design6_n35.pdb
# Van der Waals energy: 27710490.85 kcal/mol
#
# Processing design6_n34.pdb
# Van der Waals energy: 93986842.04 kcal/mol
#
# Processing design6_n39.pdb
# Van der Waals energy: 363708795.94 kcal/mol
#
# Processing design6_n40.pdb
# Van der Waals energy: 589142828.23 kcal/mol
#
# Processing design6_n37.pdb
# Van der Waals energy: 815118354.30 kcal/mol
#
# Processing design6_n32.pdb
# Van der Waals energy: 9955642.16 kcal/mol
#
# Processing design6_n31.pdb
# Van der Waals energy: 369414779.87 kcal/mol
#
# Processing design6_n3.pdb
# Van der Waals energy: 23584406.03 kcal/mol
#
# Processing design6_n29.pdb
# Van der Waals energy: 1108295.65 kcal/mol
#
# Processing design6_n28.pdb
# Van der Waals energy: 1163181.44 kcal/mol
#
# Processing design6_n23.pdb
# Van der Waals energy: 652577.06 kcal/mol
#
# Processing design6_n25.pdb
# Van der Waals energy: 2655932.26 kcal/mol
#
# Processing design6_n30.pdb
# Van der Waals energy: 140598.04 kcal/mol
#
# Processing design6_n27.pdb
# Van der Waals energy: 59951.88 kcal/mol
#
# Processing design6_n24.pdb
# Van der Waals energy: 767021.82 kcal/mol
#
# Processing design6_n26.pdb
# Van der Waals energy: 697461843.51 kcal/mol
#
# Processing design6_n21.pdb
# Van der Waals energy: 51474.75 kcal/mol
#
# Processing design5_n8.pdb
# Van der Waals energy: 17034.34 kcal/mol
#
# Processing design6_n19.pdb
# Van der Waals energy: 2441604339.58 kcal/mol
#
# Processing design5_n63.pdb
# Van der Waals energy: 1864114387.89 kcal/mol
#
# Processing design6_n17.pdb
# Van der Waals energy: 164125354.90 kcal/mol
#
# Processing design6_n0.pdb
# Van der Waals energy: 2739327.50 kcal/mol
#
# Processing design5_n9.pdb
# Van der Waals energy: 40410.57 kcal/mol
#
# Processing design5_n7.pdb
# Van der Waals energy: 72946824058.80 kcal/mol
#
# Processing design6_n10.pdb
# Van der Waals energy: 1619017566330.19 kcal/mol
#
# Processing design6_n12.pdb
# Van der Waals energy: 1297.20 kcal/mol
#
# Processing design6_n1.pdb
# Van der Waals energy: 274235782.89 kcal/mol
#
# Processing design6_n13.pdb
# Van der Waals energy: 239646.71 kcal/mol
#
# Processing design6_n11.pdb
# Van der Waals energy: 6000753179111286784.00 kcal/mol
#
# Processing design6_n14.pdb
# Van der Waals energy: 59066523047.93 kcal/mol
#
# Processing design6_n2.pdb
# Van der Waals energy: 6233373760.79 kcal/mol
#
# Processing design6_n16.pdb
# Van der Waals energy: 29211.27 kcal/mol
#
# Processing design6_n20.pdb
# Van der Waals energy: 333818350616.76 kcal/mol
#
# Processing design6_n15.pdb
# Van der Waals energy: 207396.33 kcal/mol
#
# Processing design6_n18.pdb
# Van der Waals energy: 134876599655.57 kcal/mol
#
# Processing design6_n22.pdb
# Van der Waals energy: 11205.33 kcal/mol
#
# Processing design7_n9.pdb
# Van der Waals energy: 14520.43 kcal/mol
#
# Processing design7_n8.pdb
# Van der Waals energy: 34538.79 kcal/mol
#
# Processing design7_n61.pdb
# Van der Waals energy: 154657.44 kcal/mol
#
# Processing design7_n6.pdb
# Van der Waals energy: 7338.85 kcal/mol
#
# Processing design7_n58.pdb
# Van der Waals energy: 47002900.46 kcal/mol
#
# Processing design7_n59.pdb
# Van der Waals energy: 1643065097331.66 kcal/mol
#
# Processing design7_n60.pdb
# Van der Waals energy: 3515057.71 kcal/mol
#
# Processing design7_n62.pdb
# Van der Waals energy: 176572.15 kcal/mol
#
# Processing design7_n7.pdb
# Van der Waals energy: 169966.72 kcal/mol
#
# Processing design7_n57.pdb
# Van der Waals energy: 163259.73 kcal/mol
#
# Processing design7_n56.pdb
# Van der Waals energy: 25164535.30 kcal/mol
#
# Processing design7_n52.pdb
# Van der Waals energy: 29146.30 kcal/mol
#
# Processing design7_n55.pdb
# Van der Waals energy: 2261496.66 kcal/mol
#
# Processing design7_n50.pdb
# Van der Waals energy: 18204633826.14 kcal/mol
#
# Processing design7_n49.pdb
# Van der Waals energy: 14190469724.08 kcal/mol
#
# Processing design7_n5.pdb
# Van der Waals energy: 175038.12 kcal/mol
#
# Processing design7_n53.pdb
# Van der Waals energy: 8436567604.59 kcal/mol
#
# Processing design7_n54.pdb
# Van der Waals energy: 22797783.03 kcal/mol
#
# Processing design7_n51.pdb
# Van der Waals energy: 1010670.12 kcal/mol
#
# Processing design7_n47.pdb
# Van der Waals energy: 93635396.81 kcal/mol
#
# Processing design7_n48.pdb
# Van der Waals energy: 47196344.27 kcal/mol
#
# Processing design7_n45.pdb
# Van der Waals energy: 1179067864.08 kcal/mol
#
# Processing design7_n44.pdb
# Van der Waals energy: 11521556.20 kcal/mol
#
# Processing design7_n43.pdb
# Van der Waals energy: 717389123.40 kcal/mol
#
# Processing design7_n42.pdb
# Van der Waals energy: 311222840580.20 kcal/mol
#
# Processing design7_n39.pdb
# Van der Waals energy: 116597.78 kcal/mol
#
# Processing design7_n4.pdb
# Van der Waals energy: 251838.47 kcal/mol
#
# Processing design7_n40.pdb
# Van der Waals energy: 1686822152067.51 kcal/mol
#
# Processing design7_n46.pdb
# Van der Waals energy: 104437064.73 kcal/mol
#
# Processing design7_n41.pdb
# Van der Waals energy: 1218918682.94 kcal/mol
#
# Processing design7_n38.pdb
# Van der Waals energy: 151639.44 kcal/mol
#
# Processing design7_n63.pdb
# Van der Waals energy: 279909571.50 kcal/mol
#
# Summary Report:
# PDB File                       Buried Surface Area (Å²)  H-Bonds      Hydrophobic  Salt Bridges VDW Energy (kcal/mol)
# ====================================================================================================
# design0_n16.pdb                1904.15                   17           11           2            197353922.33
# design0_n1.pdb                 1593.75                   0            15           3            106546551.24
# design0_n13.pdb                1344.79                   2            13           2            4525192545.27
# design0_n10.pdb                1698.90                   5            12           1            1710704.96
# design0_n12.pdb                1983.12                   1            20           2            758596.49
# design0_n15.pdb                1417.30                   1            11           5            53091.06
# design1_n1.pdb                 1805.60                   3            12           2            1983392428.93
# design0_n0.pdb                 1349.91                   1            16           3            628830.78
# design1_n11.pdb                1273.78                   6            6            2            2378412308962.11
# design0_n14.pdb                1050.12                   1            6            4            611.03
# design0_n9.pdb                 1381.45                   0            12           2            1262.17
# design0_n11.pdb                1655.80                   18           32           0            43594474026.28
# design1_n0.pdb                 1381.74                   0            7            0            4981.34
# design1_n12.pdb                1637.55                   12           14           5            2546535340.15
# design0_n8.pdb                 1919.16                   2            28           3            4782172453.66
# design0_n63.pdb                1750.71                   0            19           1            202964999.88
# design1_n10.pdb                1323.52                   2            14           1            7874346844.62
# design0_n7.pdb                 1673.73                   0            19           3            53946903.15
# design0_n62.pdb                1556.93                   2            10           0            174983.95
# design0_n6.pdb                 1298.58                   0            7            0            30656.12
# design0_n60.pdb                1400.08                   0            12           3            58817.09
# design0_n58.pdb                1950.43                   4            19           4            272671.55
# design0_n56.pdb                1071.18                   1            13           1            172395.19
# design0_n61.pdb                1106.16                   0            9            2            143.92
# design0_n59.pdb                1447.00                   0            16           1            1182.89
# design0_n55.pdb                1670.66                   0            18           4            4415618.51
# design0_n57.pdb                1418.73                   0            3            3            120189459.65
# design0_n54.pdb                1764.02                   1            14           6            95251809076.88
# design0_n53.pdb                1475.59                   0            6            4            117824613101.22
# design0_n51.pdb                1104.93                   2            16           2            15992117818.47
# design0_n50.pdb                1475.38                   0            13           4            1206303006.00
# design0_n45.pdb                1144.75                   0            13           3            290.28
# design0_n48.pdb                1438.85                   3            15           0            21186496.70
# design0_n47.pdb                1039.05                   0            10           2            32.28
# design0_n5.pdb                 1215.33                   3            11           3            22280183540.04
# design0_n52.pdb                1442.57                   1            17           2            3341113.67
# design0_n49.pdb                1778.36                   1            16           3            16368323.62
# design0_n46.pdb                1944.44                   0            8            3            44718717019.36
# design0_n42.pdb                1831.65                   2            23           3            502700.10
# design0_n40.pdb                1816.76                   0            17           6            327386714625.55
# design0_n39.pdb                2010.33                   5            27           1            41291248.42
# design0_n43.pdb                1660.56                   1            21           5            180272.26
# design0_n41.pdb                1472.54                   0            15           3            470205.49
# design0_n38.pdb                1706.33                   0            15           3            11649950.34
# design0_n4.pdb                 1760.51                   0            25           0            6081.13
# design0_n44.pdb                1512.96                   1            14           2            580253075.54
# design0_n37.pdb                1237.19                   0            10           1            406790.45
# design0_n36.pdb                1974.90                   11           14           2            38220416587.89
# design0_n34.pdb                1802.91                   17           31           1            53573496874.77
# design0_n30.pdb                1539.86                   0            16           3            1717201.42
# design0_n3.pdb                 1353.07                   0            6            4            71926.84
# design0_n27.pdb                1338.96                   8            11           2            32971.46
# design0_n32.pdb                1875.50                   0            19           3            42222893.89
# design0_n35.pdb                1648.88                   0            16           3            2219.74
# design0_n33.pdb                1977.15                   0            20           6            13914755.45
# design0_n31.pdb                1742.82                   0            16           5            235560049.60
# design0_n25.pdb                1358.58                   3            6            2            350902.51
# design0_n29.pdb                1768.26                   0            16           3            1993678.74
# design0_n28.pdb                1726.34                   1            19           4            73962844415.05
# design0_n22.pdb                1534.18                   0            14           2            837.99
# design0_n21.pdb                1531.43                   0            16           4            7795892.88
# design0_n19.pdb                1474.17                   0            16           3            48633.76
# design0_n20.pdb                1696.66                   0            12           4            662536.69
# design0_n26.pdb                1146.71                   1            7            2            25067.80
# design0_n2.pdb                 1807.49                   0            14           2            1261894.18
# design0_n23.pdb                1379.35                   0            13           2            13482.60
# design0_n24.pdb                1783.82                   4            15           7            1584099.07
# design0_n18.pdb                1566.85                   1            7            2            1399978112.89
# design0_n17.pdb                1621.69                   0            13           3            7843328.33
# design1_n14.pdb                1623.45                   3            13           0            97775496.27
# design1_n13.pdb                1753.36                   4            20           1            382371557697.71
# design1_n19.pdb                1771.76                   7            16           1            7631783233910.84
# design2_n1.pdb                 2246.00                   5            15           4            15557170662.77
# design1_n8.pdb                 1698.74                   0            17           3            19590760.95
# design2_n0.pdb                 1227.71                   0            10           1            90208.38
# design1_n61.pdb                1412.56                   8            17           1            2198441357380393.75
# design1_n62.pdb                1730.23                   3            10           2            10477740.30
# design1_n9.pdb                 1375.34                   1            13           3            414069054162462.56
# design1_n7.pdb                 1690.01                   0            15           2            68904345.29
# design1_n63.pdb                1557.05                   0            16           2            66614.24
# design1_n60.pdb                1707.13                   0            12           1            1080746707.68
# design1_n6.pdb                 1835.03                   3            20           1            1129084836.58
# design1_n58.pdb                1326.06                   0            8            0            40546.17
# design1_n56.pdb                1771.33                   0            14           1            1277670.42
# design1_n54.pdb                1367.53                   4            7            2            365011.87
# design1_n55.pdb                1652.30                   1            9            2            441157.59
# design1_n51.pdb                1607.07                   0            7            2            65478841.74
# design1_n57.pdb                1691.16                   0            7            5            509919040.42
# design1_n53.pdb                2200.64                   17           24           7            213834562201934.81
# design1_n52.pdb                1203.75                   2            9            2            353327.13
# design1_n59.pdb                1960.52                   7            22           2            7971139632.35
# design1_n50.pdb                1846.03                   0            14           0            130125.26
# design1_n49.pdb                1413.38                   0            12           1            19644981.26
# design1_n47.pdb                1688.31                   0            18           1            3912655.36
# design1_n44.pdb                815.65                    0            3            1            10632.56
# design1_n48.pdb                1705.37                   3            20           0            2856091.86
# design1_n43.pdb                1175.95                   1            5            0            538411942.02
# design1_n5.pdb                 1626.90                   0            10           1            1802944.20
# design1_n42.pdb                1895.31                   12           16           4            19798129730.62
# design1_n45.pdb                1267.57                   0            6            2            345560379.44
# design1_n46.pdb                1747.80                   0            20           0            124331.73
# design1_n41.pdb                1798.02                   0            15           5            18062584.00
# design1_n4.pdb                 2040.65                   9            24           0            790563476.40
# ...
# design5_n12.pdb                2891.24                   2            22           6            2139844264.18
# design5_n1.pdb                 1453.19                   0            12           3            839901762.49
# design5_n11.pdb                2285.82                   4            14           4            207813967.46
# design5_n17.pdb                1883.59                   3            14           2            8481250848290.71
# design5_n16.pdb                1780.27                   0            16           2            1178240337079.21
# design5_n13.pdb                1222.11                   0            5            1            166676209.24
# design5_n15.pdb                2202.98                   4            16           4            2873854805.35
# design5_n0.pdb                 1533.66                   0            8            1            84036587822.62
# design5_n10.pdb                1372.05                   0            7            3            125340862.50
# design4_n8.pdb                 989.54                    3            4            3            1652373129.65
# design4_n63.pdb                1848.78                   17           15           4            28771801026960.56
# design4_n61.pdb                869.72                    0            4            0            44720078500.29
# design7_n37.pdb                1311.93                   0            11           0            441097.05
# design4_n60.pdb                1542.36                   14           6            6            3924179581472.26
# design7_n34.pdb                1604.52                   1            12           0            117860.75
# design7_n36.pdb                1710.70                   3            6            3            547818992.69
# design7_n35.pdb                1244.38                   0            9            2            1431687413.32
# design7_n33.pdb                1545.71                   0            8            2            6498300564.55
# design7_n3.pdb                 1485.82                   1            4            2            1017.92
# design7_n32.pdb                1306.44                   1            5            1            257.19
# design7_n30.pdb                1361.36                   5            11           4            4592659497.43
# design7_n31.pdb                2353.52                   9            29           3            2051485157657458.75
# design7_n29.pdb                1795.48                   5            14           2            1464267.31
# design7_n24.pdb                1219.43                   8            9            3            22058342482.59
# design7_n21.pdb                1158.87                   1            9            1            2988138.81
# design7_n26.pdb                1212.02                   1            10           0            1490981.94
# design7_n23.pdb                1594.43                   10           14           3            630230603.25
# design7_n20.pdb                1753.97                   0            7            3            1848.02
# design7_n27.pdb                1229.25                   0            5            3            46787354.37
# design7_n25.pdb                1236.21                   4            11           0            143053840.34
# design7_n22.pdb                1547.35                   3            14           4            110761203.87
# design7_n28.pdb                1426.70                   1            16           3            27990541.03
# design7_n2.pdb                 1167.34                   0            8            0            1130680564.03
# design7_n19.pdb                1515.35                   6            19           2            694045396.19
# design7_n11.pdb                1482.16                   0            11           2            675139714.48
# design7_n18.pdb                1326.78                   1            6            0            1791079508.65
# design7_n15.pdb                1063.27                   4            7            1            11250901294.74
# design7_n13.pdb                1623.24                   0            9            0            24727.66
# design7_n16.pdb                1609.64                   0            14           1            70302.24
# design7_n12.pdb                1719.81                   9            9            9            1859648356.24
# design7_n17.pdb                1464.90                   2            14           2            447633511.77
# design7_n10.pdb                1193.89                   4            10           1            2489382.11
# design7_n1.pdb                 1401.22                   0            3            1            3342088174.64
# design7_n14.pdb                1270.21                   0            13           2            286764.93
# design6_n9.pdb                 1848.69                   2            18           2            273038.81
# design6_n62.pdb                1993.11                   1            19           2            12993515306.06
# design6_n63.pdb                1284.13                   2            7            0            173012.41
# design6_n8.pdb                 1733.94                   1            18           1            28624750.63
# design7_n0.pdb                 1146.30                   0            11           0            52712758973.07
# design6_n7.pdb                 1312.90                   0            21           2            63218.71
# design6_n60.pdb                1138.27                   0            17           1            2304826714.65
# design6_n61.pdb                1430.79                   0            6            2            27963453822626108.00
# design6_n6.pdb                 1129.20                   0            8            0            22948.18
# design6_n59.pdb                1409.98                   1            11           1            15727100.06
# design6_n58.pdb                1650.70                   2            9            2            24445.22
# design6_n54.pdb                1443.02                   0            14           3            116347.69
# design6_n56.pdb                1263.28                   0            10           0            445316.22
# design6_n55.pdb                1921.13                   4            17           4            9382.58
# design6_n57.pdb                1750.24                   0            14           1            38387.41
# design6_n51.pdb                1807.79                   2            18           3            21056.81
# design6_n50.pdb                1215.89                   1            19           1            721699686.47
# design6_n52.pdb                1773.20                   2            23           0            8480966.49
# design6_n53.pdb                1848.05                   2            22           5            147125.76
# design6_n46.pdb                1648.33                   2            18           5            37235449.49
# design6_n49.pdb                1681.58                   2            17           2            278233.14
# design6_n44.pdb                1904.03                   0            17           3            40419.62
# design6_n42.pdb                1825.03                   3            20           1            107011106.13
# design6_n45.pdb                1531.09                   2            11           1            19527386.24
# design6_n47.pdb                1651.48                   0            16           5            78427.51
# design6_n48.pdb                1307.20                   3            10           1            317133237.94
# design6_n43.pdb                1288.95                   1            14           2            11727327.23
# design6_n5.pdb                 1806.46                   0            15           5            2309309.31
# design6_n41.pdb                1849.13                   1            14           3            1251918.72
# design6_n4.pdb                 1900.58                   1            18           2            535286.34
# design6_n36.pdb                1238.77                   2            13           1            85912.55
# design6_n38.pdb                1112.90                   28           11           4            665437056.28
# design6_n33.pdb                1737.28                   1            18           1            70167059.33
# design6_n35.pdb                2055.02                   1            9            3            27710490.85
# design6_n34.pdb                998.20                    0            8            2            93986842.04
# design6_n39.pdb                1690.52                   2            17           1            363708795.94
# design6_n40.pdb                1906.20                   1            13           4            589142828.23
# design6_n37.pdb                1152.86                   4            12           0            815118354.30
# design6_n32.pdb                1657.44                   4            20           2            9955642.16
# design6_n31.pdb                1566.91                   1            13           3            369414779.87
# design6_n3.pdb                 1304.72                   5            15           2            23584406.03
# design6_n29.pdb                1420.17                   5            15           2            1108295.65
# design6_n28.pdb                1710.46                   0            15           2            1163181.44
# design6_n23.pdb                1419.62                   1            21           1            652577.06
# design6_n25.pdb                1514.60                   0            16           2            2655932.26
# design6_n30.pdb                1867.02                   1            12           2            140598.04
# design6_n27.pdb                1457.13                   1            16           0            59951.88
# design6_n24.pdb                1003.96                   0            10           2            767021.82
# design6_n26.pdb                1966.68                   2            16           1            697461843.51
# design6_n21.pdb                1849.75                   1            22           1            51474.75
# design5_n8.pdb                 1824.46                   0            16           3            17034.34
# design6_n19.pdb                1427.47                   5            7            1            2441604339.58
# design5_n63.pdb                1513.57                   4            16           1            1864114387.89
# design6_n17.pdb                1482.39                   8            14           1            164125354.90
# design6_n0.pdb                 1418.07                   4            14           2            2739327.50
# design5_n9.pdb                 1497.14                   0            6            1            40410.57
# design5_n7.pdb                 2279.44                   3            18           3            72946824058.80
# design6_n10.pdb                1319.26                   0            20           1            1619017566330.19
# design6_n12.pdb                1682.49                   1            19           1            1297.20
# design6_n1.pdb                 1439.66                   11           22           3            274235782.89
# design6_n13.pdb                1560.49                   5            22           2            239646.71
# design6_n11.pdb                1760.86                   2            14           4            6000753179111286784.00
# design6_n14.pdb                1575.25                   1            16           3            59066523047.93
# design6_n2.pdb                 1845.08                   9            18           0            6233373760.79
# design6_n16.pdb                1578.56                   0            11           2            29211.27
# design6_n20.pdb                1313.26                   0            9            1            333818350616.76
# design6_n15.pdb                1863.90                   1            11           1            207396.33
# design6_n18.pdb                1059.60                   2            16           0            134876599655.57
# design6_n22.pdb                946.97                    1            12           3            11205.33
# design7_n9.pdb                 1144.92                   1            8            2            14520.43
# design7_n8.pdb                 841.77                    0            4            0            34538.79
# design7_n61.pdb                1897.67                   0            13           2            154657.44
# design7_n6.pdb                 1103.79                   1            2            2            7338.85
# design7_n58.pdb                2011.04                   0            13           2            47002900.46
# design7_n59.pdb                1698.21                   0            14           1            1643065097331.66
# design7_n60.pdb                1214.32                   1            10           1            3515057.71
# design7_n62.pdb                1816.69                   0            13           4            176572.15
# design7_n7.pdb                 1651.18                   1            16           2            169966.72
# design7_n57.pdb                1634.94                   0            13           4            163259.73
# design7_n56.pdb                1785.12                   4            13           2            25164535.30
# design7_n52.pdb                1506.57                   0            5            3            29146.30
# design7_n55.pdb                1512.84                   1            12           3            2261496.66
# design7_n50.pdb                1144.15                   0            8            1            18204633826.14
# design7_n49.pdb                1382.68                   5            11           1            14190469724.08
# design7_n5.pdb                 1157.20                   3            10           0            175038.12
# design7_n53.pdb                1458.92                   1            11           2            8436567604.59
# design7_n54.pdb                1600.23                   3            11           2            22797783.03
# design7_n51.pdb                1380.87                   2            9            2            1010670.12
# design7_n47.pdb                2095.36                   1            16           4            93635396.81
# design7_n48.pdb                1338.94                   2            9            2            47196344.27
# design7_n45.pdb                1531.75                   3            14           2            1179067864.08
# design7_n44.pdb                1549.59                   6            17           0            11521556.20
# design7_n43.pdb                1534.12                   1            15           2            717389123.40
# design7_n42.pdb                1181.52                   6            10           1            311222840580.20
# design7_n39.pdb                1620.17                   0            14           3            116597.78
# design7_n4.pdb                 1096.33                   1            6            1            251838.47
# design7_n40.pdb                1515.43                   3            11           1            1686822152067.51
# design7_n46.pdb                1556.29                   7            16           2            104437064.73
# design7_n41.pdb                2020.95                   2            10           4            1218918682.94
# design7_n38.pdb                1305.70                   0            6            1            151639.44
# design7_n63.pdb                1582.06                   1            11           1            279909571.50

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
